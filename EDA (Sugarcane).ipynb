# %% [markdown]
# # SUGARCANE PRODUCTION EDA PROJECT

# %%
# Importing libraries
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

# %%
df = pd.read_csv("SugarCane.csv")

# %%
df.shape
# Out:
# (103, 7)

# %%
df.head()
# Out:
#    Unnamed: 0   Country      Continent Production (Tons)  \
# 0           0    Brazil  South America       768.678.382
# 1           1     India           Asia       348.448.000
# 2           2     China           Asia       123.059.739
# 3           3  Thailand           Asia        87.468.496
# 4           4  Pakistan           Asia        65.450.704
#
#   Production per Person (Kg) Acreage (Hectare) Yield (Kg / Hectare)
# 0                  3.668,531        10.226.205             75.167,5
# 1                     260721         4.950.000             70.393,5
# 2                      88287         1.675.215             73.459,1
# 3                  1.264,303         1.336.575             65.442,2
# 4                     324219         1.130.820               57.879

# %%
## Acreage gives us how land we have for sugarcane production

# %% [markdown]
# # Data Cleaning

# %%
df["Production (Tons)"] = df["Production (Tons)"].str.replace(".","")
df["Production per Person (Kg)"] = df["Production per Person (Kg)"].str.replace(".","").str.replace(",",".")
df["Acreage (Hectare)"] = df["Acreage (Hectare)"].str.replace(".","")
df["Yield (Kg / Hectare)"]= df["Yield (Kg / Hectare)"].str.replace(".","").str.replace(",",".")

# %%
df.head()
# Out:
#    Unnamed: 0   Country      Continent Production (Tons)  \
# 0           0    Brazil  South America         768678382
# 1           1     India           Asia         348448000
# 2           2     China           Asia         123059739
# 3           3  Thailand           Asia          87468496
# 4           4  Pakistan           Asia          65450704
#
#   Production per Person (Kg) Acreage (Hectare) Yield (Kg / Hectare)
# 0                   3668.531          10226205              75167.5
# 1                     260721           4950000              70393.5
# 2                      88287           1675215              73459.1
# 3                   1264.303           1336575              65442.2
# 4                     324219           1130820                57879

# %%
df = df.drop( "Unnamed: 0", axis = 1)

# %%
df.rename(columns= {"Production (Tons)": "Production"}, inplace = True)
df.rename(columns= {"Production per Person (Kg)": "Production_per_person"}, inplace = True)
df.rename(columns= {"Acreage (Hectare)": "Acreage"}, inplace = True)
df.rename(columns= {"Yield (Kg / Hectare)": "Yield"}, inplace = True)

# %%
df.head()
# Out:
#     Country      Continent Production Production_per_person   Acreage    Yield
# 0    Brazil  South America  768678382              3668.531  10226205  75167.5
# 1     India           Asia  348448000                260721   4950000  70393.5
# 2     China           Asia  123059739                 88287   1675215  73459.1
# 3  Thailand           Asia   87468496              1264.303   1336575  65442.2
# 4  Pakistan           Asia   65450704                324219   1130820    57879

# %% [markdown]
# ## CHECKING THE NULL VALUES

# %%
df.isnull().sum()
# Out:
# Country                  0
# Continent                0
# Production               0
# Production_per_person    0
# Acreage                  1
# Yield                    1
# dtype: int64

# %%
df[df["Acreage"].isnull()]
# Out:
#      Country Continent Production Production_per_person Acreage Yield
# 99  Djibouti    Africa         53                    51     NaN   NaN

# %% [markdown]
# ## DROPPING THE NULL VALUES

# %%
df = df.dropna().reset_index().drop("index", axis = 1)

# %%
df
# Out:
#        Country      Continent Production Production_per_person   Acreage  \
# 0       Brazil  South America  768678382              3668.531  10226205
# 1        India           Asia  348448000                260721   4950000
# 2        China           Asia  123059739                 88287   1675215
# 3     Thailand           Asia   87468496              1264.303   1336575
# 4     Pakistan           Asia   65450704                324219   1130820
# ..         ...            ...        ...                   ...       ...
# 97       Spain         Europe        394                     8         9
# 98     Lebanon           Asia         97                    16         3
# 99   Singapore           Asia         50                     9         2
# 100      Samoa        Oceania         12                     6         1
# 101      Syria           Asia          1                     0         0
#
#        Yield
# 0    75167.5
# 1    70393.5
# 2    73459.1
# 3    65442.2
# 4      57879
# ..       ...
# 97   43596.5
# 98   28386.4
# 99        25
# 100  11949.8
# 101  83034.2
#
# [102 rows x 6 columns]

# %% [markdown]
# ### Number of unique values

# %%
df.nunique()
# Out:
# Country                  102
# Continent                  6
# Production               102
# Production_per_person    101
# Acreage                  101
# Yield                    102
# dtype: int64

# %%
df.dtypes
# Out:
# Country                  object
# Continent                object
# Production               object
# Production_per_person    object
# Acreage                  object
# Yield                    object
# dtype: object

# %% [markdown]
# #### COnverting the datatypes into float

# %%
df.dtypes
# Out:
# Country                   object
# Continent                 object
# Production               float64
# Production_per_person    float64
# Acreage                  float64
# Yield                    float64
# dtype: object

# %% [markdown]
# # Univariate Analysis

# %%
df.head()
# Out:
#     Country      Continent   Production  Production_per_person     Acreage  \
# 0    Brazil  South America  768678382.0               3668.531  10226205.0
# 1     India           Asia  348448000.0             260721.000   4950000.0
# 2     China           Asia  123059739.0              88287.000   1675215.0
# 3  Thailand           Asia   87468496.0               1264.303   1336575.0
# 4  Pakistan           Asia   65450704.0             324219.000   1130820.0
#
#      Yield
# 0  75167.5
# 1  70393.5
# 2  73459.1
# 3  65442.2
# 4  57879.0

# %% [markdown]
# ## Continents producing SugarCane

# %%
df["Continent"].value_counts()
# Out:
# Continent
# Africa           38
# Asia             25
# North America    22
# South America    11
# Oceania           4
# Europe            2
# Name: count, dtype: int64

# %%
df["Continent"].value_counts().plot(kind = "bar")
# Out:
# <Axes: xlabel='Continent'>

# %% [markdown]
# Africa has maximum number of countries which produces sugarcane.

# %%
df.describe()
# Out:
#          Production  Production_per_person       Acreage          Yield
# count  1.020000e+02             102.000000  1.020000e+02     102.000000
# mean   1.850372e+07          112952.435755  2.498981e+05   52628.078431
# std    8.419149e+07          176651.341929  1.137003e+06   30504.676683
# min    1.000000e+00               0.000000  0.000000e+00      10.000000
# 25%    6.251875e+04            3671.910000  1.104000e+03   29072.025000
# 50%    1.440044e+06           25572.500000  1.655800e+04   54108.950000
# 75%    6.426824e+06          146384.750000  8.047400e+04   73282.700000
# max    7.686784e+08          951087.000000  1.022620e+07  129049.300000

# %% [markdown]
# ## Checking outliers

# %%
plt.figure(figsize = (10,8))
plt.subplot(2,2,1)
sns.boxplot(df["Production"])
plt.title("Production")
plt.subplot(2,2,2)
sns.boxplot(df["Production_per_person"])
plt.title("Production_per_person")
plt.subplot(2,2,3)
sns.boxplot(df["Acreage"])
plt.title("Acreage")
plt.subplot(2,2,4)
sns.boxplot(df["Yield"])
plt.title("Yield")
plt.show()

# %% [markdown]
# we have outliers in the data but outliers are required here as it shows the countries which has maximum production. And then we can see what are the reasons for outliers.

# %% [markdown]
# ## Distribution of the columns

# %%
plt.figure(figsize = (10,10))
plt.subplot(2,2,1)
sns.distplot(df["Production"])
plt.title("Production")
plt.subplot(2,2,2)
sns.distplot(df["Production_per_person"])
plt.title("Production_per_person")
plt.subplot(2,2,3)
sns.distplot(df["Acreage"])
plt.title("Acreage")
plt.subplot(2,2,4)
sns.distplot(df["Yield"])
plt.title("Yield")
plt.show()
# Out:
# C:\Users\THINKPAD\AppData\Local\Temp\ipykernel_16240\695158843.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Production"])
# D:\Anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\THINKPAD\AppData\Local\Temp\ipykernel_16240\695158843.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Production_per_person"])
# D:\Anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\THINKPAD\AppData\Local\Temp\ipykernel_16240\695158843.py:9: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Acreage"])
# D:\Anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\THINKPAD\AppData\Local\Temp\ipykernel_16240\695158843.py:12: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Yield"])
# D:\Anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.violinplot(df["Production"])
# Out:
# <Axes: >

# %% [markdown]
# # Bivariate Analysis

# %%
df.head()
# Out:
#     Country      Continent   Production  Production_per_person     Acreage  \
# 0    Brazil  South America  768678382.0               3668.531  10226205.0
# 1     India           Asia  348448000.0             260721.000   4950000.0
# 2     China           Asia  123059739.0              88287.000   1675215.0
# 3  Thailand           Asia   87468496.0               1264.303   1336575.0
# 4  Pakistan           Asia   65450704.0             324219.000   1130820.0
#
#      Yield
# 0  75167.5
# 1  70393.5
# 2  73459.1
# 3  65442.2
# 4  57879.0

# %% [markdown]
# ## Countries producing Maximum sugarcane

# %%
df_new = df[["Country","Production"]].set_index("Country")    # creating a new df with just country and production with country set as index

# %%
df_new
# Out:
#             Production
# Country
# Brazil     768678382.0
# India      348448000.0
# China      123059739.0
# Thailand    87468496.0
# Pakistan    65450704.0
# ...                ...
# Spain            394.0
# Lebanon           97.0
# Singapore         50.0
# Samoa             12.0
# Syria              1.0
#
# [102 rows x 1 columns]

# %%
df_new["Production_percent"] = df_new["Production"]*100/df_new["Production"].sum()

# %%
df_new
# Out:
#             Production  Production_percent
# Country
# Brazil     768678382.0        4.072729e+01
# India      348448000.0        1.846200e+01
# China      123059739.0        6.520138e+00
# Thailand    87468496.0        4.634389e+00
# Pakistan    65450704.0        3.467809e+00
# ...                ...                 ...
# Spain            394.0        2.087551e-05
# Lebanon           97.0        5.139401e-06
# Singapore         50.0        2.649176e-06
# Samoa             12.0        6.358022e-07
# Syria              1.0        5.298352e-08
#
# [102 rows x 2 columns]

# %%
df_new["Production_percent"].plot(kind = "pie", autopct = "%.2f")
# Out:
# <Axes: ylabel='Production_percent'>

# %% [markdown]
# Brazil, India and China have 65% of production of sugarcane

# %%
df[["Country","Production"]].set_index("Country").sort_values("Production", ascending = False).head(15).plot(kind = "bar")
# Out:
# <Axes: xlabel='Country'>

# %% [markdown]
# ### Analysis : The country "Brazil" produces the maximum sugarcane out of all countries

# %% [markdown]
# ## Country having the biggest land

# %%
df_acr = df.sort_values("Acreage", ascending = False).head(15)
ax = sns.barplot(data = df_acr,  x= "Country", y = "Acreage")
ax.set_xticklabels(ax.get_xticklabels(),rotation =90)
plt.show()

# %% [markdown]
# ### Analysis : The country : "Brazil" has the largest land among all

# %% [markdown]
# ## HIghest Yeild per Hectare

# %%
df_yield = df.sort_values("Yield", ascending = False).head(15)
ax = sns.barplot(data = df_yield,  x= "Country", y = "Yield")
ax.set_xticklabels(ax.get_xticklabels(),rotation =90)
plt.show()

# %% [markdown]
# ### Guatemala has the highest yield per hectare

# %% [markdown]
# ## Highest Production

# %%
df_yield = df.sort_values("Production_per_person", ascending = False).head(15)
ax = sns.barplot(data = df_yield,  x= "Country", y = "Production_per_person")
ax.set_xticklabels(ax.get_xticklabels(),rotation =90)
plt.show()

# %% [markdown]
# ### Production per Person is highest in Paraguay

# %% [markdown]
# ## Do countries with highest land produce more sugarcane?

# %%
sns.scatterplot(data = df, x = "Acreage", y = "Production", hue = "Continent" )
# Out:
# <Axes: xlabel='Acreage', ylabel='Production'>

# %% [markdown]
# ### Overall increase in land increases the production i.e. countries with highest land produces more sugarcane

# %% [markdown]
# ## Do countries which yield more sugarcane per hectare produces more sugarcane in total?

# %%
sns.scatterplot(data = df.head(20), x = "Yield" , y = "Production", hue = "Country")
# Out:
# <Axes: xlabel='Yield', ylabel='Production'>

# %% [markdown]
# # Analysis for Continent

# %%
df_continent = df.groupby("Continent").sum()

# %%
df_continent["number_of_countries"] = df.groupby("Continent").count()["Country"]

# %%
df_continent
# Out:
#                                                          Country   Production  \
# Continent
# Africa         EgyptSouth AfricaKenyaSwazilandSudanZambiaMaur...   89681472.0
# Asia           IndiaChinaThailandPakistanIndonesiaPhilippines...  721930425.0
# Europe                                             PortugalSpain       5823.0
# North America  MexicoGuatemalaUnited States of AmericaCubaEl ...  173995947.0
# Oceania                       AustraliaFijiPapua New GuineaSamoa   36177574.0
# South America  BrazilColombiaArgentinaPeruEcuadorBoliviaParag...  865588126.0
#
#                Production_per_person     Acreage      Yield  \
# Continent
# Africa                   2332636.293   1439089.0  2142107.5
# Asia                     1857769.303  10608319.0  1171871.4
# Europe                       536.000        71.0   131870.9
# North America            3796081.508   1581983.0  1082602.4
# Oceania                    28593.605    490909.0   162419.1
# South America            3505531.738  11369236.0   677192.7
#
#                number_of_countries
# Continent
# Africa                          38
# Asia                            25
# Europe                           2
# North America                   22
# Oceania                          4
# South America                   11

# %% [markdown]
# ## Which continent produces maximum sugarcane?

# %%
df_continent["Production"].sort_values(ascending =  False).plot(kind = "bar")
# Out:
# <Axes: xlabel='Continent'>

# %% [markdown]
# ### South America produces more sugarcane than the rest of the continents

# %% [markdown]
# ## Do number of countries in a Continent effects production of sugarcane?

# %%
continent_names = df_continent.index.to_list()
sns.lineplot(data = df_continent,x = "number_of_countries", y= "Production" )
plt.xticks(df_continent["number_of_countries"], continent_names, rotation =90)
plt.show()
# Out:
# D:\Anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# D:\Anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ### We can observe that even though Africa has highest number of countries, it produces less sugarcane

# %% [markdown]
# ### Even though South America has around low to mid number of countries, it produces more sugarcane

# %% [markdown]
# ## Do continent with highest land produces more sugarcane?

# %%
sns.lineplot(data = df_continent,x = "Acreage", y= "Production" )
# Out:
# D:\Anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# D:\Anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Acreage', ylabel='Production'>

# %% [markdown]
# ## Production distribution by continent

# %%
df_continent["Production"].plot(kind = "pie", autopct = "%.2f%%")
plt.title('Production Distribution by Continent')
plt.show()

# %% [markdown]
# ### we can notice that south america produces around 45.86% of sugarcane and Asia produces 38.35%

# %% [markdown]
# ### WE can also see that even though africa has highest number of continents, still produces less amount of sugarcane
