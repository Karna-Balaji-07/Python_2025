# %% [markdown]
# # 1. Bubble Sort Algorithm

# %%
def bubblesort(arr):
    n = len(arr)
    for i in range(n):
        swapped = False
        for j in range(0,n-i-1):
            if arr[j] > arr[j+1]:
                arr[j],arr[j+1] = arr[j+1],arr[j]
                swapped = True
        if swapped == False:
            break

    print(arr)

arr = [5,3,1,8,6,4,9,5]
bubblesort(arr)
# Out:
# [1, 3, 4, 5, 5, 6, 8, 9]

# %% [markdown]
# # 2. SELECTION SORT

# %%
def selectionsort(arr):
    n = len(arr)
    for i in range(n-1):
        min_index = i
        for j in range(i+1,n):
            if arr[j] < arr[min_index]:
                min_index = j
        arr[i],arr[min_index] = arr[min_index],arr[i]
    
    print(arr)

arr = [7,3,5,9,45,67,9,3,3,8,7,4,4,6,8,75,3]
selectionsort(arr)
# Out:
# [3, 3, 3, 3, 4, 4, 5, 6, 7, 7, 8, 8, 9, 9, 45, 67, 75]

# %% [markdown]
# # 3. INSERTION SORT

# %%
def insertionsort(arr):
    n = len(arr)
    for i in range(1,n):
        key = arr[i]
        j = i-1
        while j >=0 and arr[j] > key:
            arr[j+1] = arr[j]
            j -= 1
        arr[j+1] = key
    print(arr)

arr = [1,4,8,32,7,97,3,5,86]
insertionsort(arr)
# Out:
# [1, 3, 4, 5, 7, 8, 32, 86, 97]

# %% [markdown]
# # 4. MERGE SORT

# %%
def merge(arr,left,mid,right):
    n1 = mid - left + 1
    n2 = right - mid

    L = [0]*n1
    R = [0]*n2

    for i in range(n1):
        L[i] = arr[left+i]
    for j in range(n2):
        R[j] = arr[mid+1+j]

    i = 0
    j = 0
    k = left

    while i < n1 and j < n2:
        if L[i] <= R[j]:
            arr[k] = L[i]
            i += 1
        else:
            arr[k] = R[j]
            j += 1
        k += 1
    
    while i < n1:
        arr[k] = L[i]
        i += 1
        k += 1
    while j < n2:
        arr[k] = R[j]
        j += 1
        k += 1
    

def mergesort(arr,left,right):
    if left < right:
        mid = (left+right)//2
        mergesort(arr,left,mid)
        mergesort(arr,mid+1,right)
        merge(arr,left,mid,right)


arr = [12,11,13,5,6,2,9]
mergesort(arr,0,len(arr)-1)
print(arr)
# Out:
# [2, 5, 6, 9, 11, 12, 13]
