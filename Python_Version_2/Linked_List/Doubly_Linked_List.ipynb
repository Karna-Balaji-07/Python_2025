# %% [markdown]
# # Doubly Linked List

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = self.prev =  None

# %% [markdown]
# # Insert at front of the linked list

# %%
def insert_front(head, value):
    newnode = Node(value)
    prev = None
    newnode.next = head
    if head is not None:
        head.prev = newnode

    newnode.prev = None
    return newnode

def traversal(head):
    curr = head
    while curr is not None:
        print(curr.data,end="..")
        curr = curr.next
    print()

head = Node(2)
head.next = Node(3)
head.next.prev = head
head.next.next = Node(4)
head.next.next.prev = head.next

result1 = insert_front(head,10)
traversal(result1)
# Out:
# 10..2..3..4..

# %% [markdown]
# # Insert node at the end of the linked list

# %%
def insert_end(head, value):
