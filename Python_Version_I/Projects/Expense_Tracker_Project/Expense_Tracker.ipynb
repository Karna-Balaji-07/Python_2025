# %%
# Importing all the necessary libraries
import os
from datetime import datetime
import csv
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # File Setup function

# %%
# Function to setup file
file_name = "Expenses.csv"
def setup():
    if not os.path.exists(file_name):
        with open(file_name,'w',newline="") as file:
            writer = csv.writer(file)
            writer.writerow(['Date','Expense/Income','Category','Payment Method','Amount','Balance'])
setup()
df = pd.read_csv(file_name)
print(df.head())
# Out:
#                   Date Expense/Income   Category Payment Method  Amount  \
# 0  2025-02-12 18:57:57        Expense       Food           Cash   200.0
# 1  2025-02-12 18:58:08         Income     Salary   Bank to Bank  1000.0
# 2  2025-02-12 18:58:19         Income  Freelance   Bank to Bank   250.0
# 3  2025-02-12 18:58:42        Expense  Transport           Cash   250.0
# 4  2025-02-12 18:59:06        Expense       Food            UPI   270.0
#
#    Balance
# 0   9800.0
# 1  10800.0
# 2  11050.0
# 3  10800.0
# 4  10530.0

# %% [markdown]
# # Expense Function

# %%
# Expense function 
def expenses():
    EXPENSE_CATEGORIES = {
        1: "Food", 2: "Transport", 3: "Housing", 4: "Entertainment",
        5: "Shopping", 6: "Health", 7: "Education", 8: "Travel",
        9: "Bills", 10: "Miscellaneous"
    }

    
    PAYMENT_METHODS = {
        1: "Cash",
        2: "Credit Card",
        3: "Debit Card",
        4: "Bank Transfer",
        5: "UPI",
        6: "Mobile Wallet",
        7: "Other"
    }

    global balance
    print("\n" + "="*40)
    print(" 📉 Expense Transaction ")
    print("="*40)
    amount = float(input("Enter the expense amount : "))
    print("\nSelect Category Type : ->")
    for key,value in EXPENSE_CATEGORIES.items():
        print(f'{key} : {value}')
    Category = int(input("\nEnter Category: "))
    category = EXPENSE_CATEGORIES.get(Category,"Misc")
    print("\nSelect Payment Method : ->")
    for key,value in PAYMENT_METHODS.items():
        print(f'{key} : {value}')
    payment_method = int(input("\nEnter Payment Method: "))
    method = PAYMENT_METHODS.get(payment_method,'Confidential')

    if amount > balance:
        print("Insufficient Funds available in bank")
    
    balance -=  amount
    date = datetime.now().strftime("%Y-%m-%d %H:%M:%S")

    with open(file_name,'a',newline="") as file:
        writer = csv.writer(file)
        writer.writerow([date,'Expense',category,method,amount,balance])
    
    # Display Summary
    print("\n-------------------------")
    print(" ✅ Expense Recorded! ")
    print("-------------------------")
    print(f" Amount        : ₹{amount:.2f}")
    print(f" Category      : {category}")
    print(f" Payment Mode  : {method}")
    print(f" Remaining Bal : ₹{balance:.2f}")
    print("-------------------------\n")

# %% [markdown]
# #### INCOME FUNCTION

# %%
# Income funciton

def income():
    INCOME_CATEGORIES = {
    1: "Salary", 2: "Freelance", 3: "Investments", 4: "Gifts",
    5: "Rental Income", 6: "Business Income", 7: "Other"
}
    global balance
    print("\n" + "="*40)
    print(" 💰 Income Transaction ")
    print("="*40)
    date = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
    amount = float(input("\nEnter income: "))
    print("\nSelect Income Category : ->")
    for key, value in INCOME_CATEGORIES.items():
        print(f"{key}: {value}")
    category = int(input("\nEnter Income Category: "))
    income_category = INCOME_CATEGORIES.get(category, "Other")
    
    
    balance += amount
    file_name = "Expenses.csv"

    with open(file_name,'a',newline="") as file:
        writer = csv.writer(file)
        writer.writerow([date,'Income',income_category,'Bank to Bank',amount,balance])
    
      # Display Summary
    print("\n-------------------------")
    print(" ✅ Income Recorded! ")
    print("-------------------------")
    print(f" Amount        : ₹{amount:.2f}")
    print(f" Source       : {income_category}")
    print(f" New Balance  : ₹{balance:.2f}")
    print("-------------------------\n")

# %% [markdown]
# #### DISPLAYING ALL TRANSACTIONS

# %%
# Displaying all the transactions
def transcations_list():
    try:
        dataframe = pd.read_csv('Expenses.csv')
        if dataframe.empty:
            print("Transaction list is empty. Please make transactions to view the list")
            return 
        
        print("\n" + "="*75)
        print(" 📜 TRANSACTION LIST ".center(75))
        print("="*75)

        # Define column widths
        col_widths = {
            "Date": 20, "Expense/Income": 15, "Category": 15, 
            "Payment Method": 20, "Amount": 10, "Balance": 10
        }

        # Print headers
        print(f"{'Date'.ljust(col_widths['Date'])} | {'Type'.ljust(col_widths['Expense/Income'])} | "
              f"{'Category'.ljust(col_widths['Category'])} | {'Payment Method'.ljust(col_widths['Payment Method'])} | "
              f"{'Amount'.rjust(col_widths['Amount'])} | {'Balance'.rjust(col_widths['Balance'])}")
        print("-" * 75)

        # Print each row
        for _, row in dataframe.iterrows():
            print(f"{str(row['Date']).ljust(col_widths['Date'])} | {row['Expense/Income'].ljust(col_widths['Expense/Income'])} | "
                  f"{row['Category'].ljust(col_widths['Category'])} | {row['Payment Method'].ljust(col_widths['Payment Method'])} | "
                  f"{str(row['Amount']).rjust(col_widths['Amount'])} | {str(row['Balance']).rjust(col_widths['Balance'])}")

        print("="*75 + "\n")

    except FileNotFoundError:
        print("\n❌ File does not exist. No transactions recorded yet.\n")

# %% [markdown]
# #### DISPLAY EXPENSE TRANSACTION

# %%
# Display expense transactions
def expense_transaction():
    try:
        dataframe = pd.read_csv('Expenses.csv')
        if dataframe.empty:
            print("transcations list is empty. Please make transactions to view the list")
            return
        
        expenses_list = dataframe[dataframe['Expense/Income'] == 'Expense']

        if expenses_list.empty:
            print("\n⚠️  Expenses transaction list is empty. Please add expense transactions.\n")
            return

        print("\n" + "="*75)
        print(" 💰 EXPENSE TRANSACTIONS ".center(75))
        print("="*75)

        # Define column widths
        col_widths = {
            "Date": 20, "Category": 15, "Payment Method": 20, "Amount": 10, "Balance": 10
        }

        # Print headers
        print(f"{'Date'.ljust(col_widths['Date'])} | {'Category'.ljust(col_widths['Category'])} | "
              f"{'Payment Method'.ljust(col_widths['Payment Method'])} | "
              f"{'Amount'.rjust(col_widths['Amount'])} | {'Balance'.rjust(col_widths['Balance'])}")
        print("-" * 75)

        # Print each expense row
        for _, row in expenses_list.iterrows():
            print(f"{str(row['Date']).ljust(col_widths['Date'])} | {row['Category'].ljust(col_widths['Category'])} | "
                  f"{row['Payment Method'].ljust(col_widths['Payment Method'])} | "
                  f"{str(row['Amount']).rjust(col_widths['Amount'])} | {str(row['Balance']).rjust(col_widths['Balance'])}")

        print("="*75 + "\n")

    except FileNotFoundError:
        print("\n❌ File does not exist. No transactions recorded yet.\n")

# %% [markdown]
# #### INCOME TRANSACTION

# %%
# Display Income transactions
def income_transaction():
    try:
        dataframe = pd.read_csv('Expenses.csv')
        if dataframe.empty:
            print("transcations list is empty. Please make transactions to view the list")
            return
        
        income_list = dataframe[dataframe['Expense/Income'] == 'Income']

        if income_list.empty:
            print("\n⚠️  Income transaction list is empty. Please add income transactions.\n")
            return

        print("\n" + "="*75)
        print(" 💰 INCOME TRANSACTIONS ".center(75))
        print("="*75)

        # Define column widths
        col_widths = {
            "Date": 20, "Category": 15, "Payment Method": 20, "Amount": 10, "Balance": 10
        }

        # Print headers
        print(f"{'Date'.ljust(col_widths['Date'])} | {'Category'.ljust(col_widths['Category'])} | "
              f"{'Payment Method'.ljust(col_widths['Payment Method'])} | "
              f"{'Amount'.rjust(col_widths['Amount'])} | {'Balance'.rjust(col_widths['Balance'])}")
        print("-" * 75)

        # Print each income row
        for _, row in income_list.iterrows():
            print(f"{str(row['Date']).ljust(col_widths['Date'])} | {row['Category'].ljust(col_widths['Category'])} | "
                  f"{row['Payment Method'].ljust(col_widths['Payment Method'])} | "
                  f"{str(row['Amount']).rjust(col_widths['Amount'])} | {str(row['Balance']).rjust(col_widths['Balance'])}")

        print("="*75 + "\n")

    except FileNotFoundError:
        print("\n❌ File does not exist. No transactions recorded yet.\n")

# %% [markdown]
# #### EXPENSE CATEGORY TRANSACTIONS

# %%
# display expense_category_transactions
def expense_category_transactions():
    try:
        dataframe = pd.read_csv('Expenses.csv')
        if dataframe.empty:
            print("Transaction list is empty. Please make transactions to view the list")
            return
        
        expense_category = dataframe[dataframe['Expense/Income'] == 'Expense']

        if expense_category.empty:
            print("\n⚠️  Expense transaction list is empty. Please add expense transactions.\n")
            return

        # Grouping expenses by category
        category_summary = expense_category.groupby('Category')['Amount'].sum().reset_index()

        print("\n" + "="*65)
        print(" 📊 EXPENSES BY CATEGORY ".center(65))
        print("="*65)

        # Define column widths
        col_widths = {
            "Category": 25, "Total Amount": 15
        }

        # Print headers
        print(f"{'Category'.ljust(col_widths['Category'])} | {'Total Amount'.rjust(col_widths['Total Amount'])}")
        print("-" * 65)

        # Print each category row
        for _, row in category_summary.iterrows():
            print(f"{row['Category'].ljust(col_widths['Category'])} | {str(row['Amount']).rjust(col_widths['Total Amount'])}")

        print("="*65 + "\n")

    except FileNotFoundError:
        print("\n❌ File not found. No transactions recorded yet.\n")

# %% [markdown]
# #### INCOME CATEGORY TRANSACTIONS

# %%
# Display income category transactions
def income_category_transactions():
    try:
        dataframe = pd.read_csv('Expenses.csv')
        if dataframe.empty:
            print("Transaction list is empty. Please make transactions to view the list")
            return
        
        income_category = dataframe[dataframe['Expense/Income'] == 'Income']

        if income_category.empty:
            print("\n⚠️  Income transaction list is empty. Please add income transactions.\n")
            return

        # Grouping income by category
        category_summary = income_category.groupby('Category')['Amount'].sum().reset_index()

        print("\n" + "="*65)
        print(" 💰 INCOME BY CATEGORY ".center(65))
        print("="*65)

        # Define column widths
        col_widths = {
            "Category": 25, "Total Amount": 15
        }

        # Print headers
        print(f"{'Category'.ljust(col_widths['Category'])} | {'Total Amount'.rjust(col_widths['Total Amount'])}")
        print("-" * 65)

        # Print each category row
        for _, row in category_summary.iterrows():
            print(f"{row['Category'].ljust(col_widths['Category'])} | {str(row['Amount']).rjust(col_widths['Total Amount'])}")

        print("="*65 + "\n")

    except FileNotFoundError:
        print("\n❌ File not found. No transactions recorded yet.\n")

# %% [markdown]
# #### VISUALIZATIONS

# %%
import pandas as pd
import matplotlib.pyplot as plt

file_name = "Expenses.csv"

# Helper to read CSV
def load_data():
    try:
        dataframe = pd.read_csv(file_name)
        if dataframe.empty:
            print("Transaction list is empty. Please make transactions to view the list")
            return None
        dataframe['Date'] = pd.to_datetime(dataframe['Date'])
        return dataframe
    except FileNotFoundError:
        print(f"{file_name} not found.")
        return None


# 1. Income vs Expense → Pie Chart
def income_vs_expense():
    df = load_data()
    if df is None:
        return
    
    summary = df.groupby('Expense/Income')['Amount'].sum()
    plt.figure(figsize=(8, 6))
    plt.pie(summary, labels=summary.index, autopct='%1.1f%%', colors=['green', 'red'], startangle=140)
    plt.title('Income vs Expense Distribution')
    plt.axis('equal')
    plt.show()


# 2. Expense by Categories → Bar Chart
def expense_by_categories():
    df = load_data()
    if df is None:
        return

    expense_df = df[df['Expense/Income'] == 'Expense']
    if expense_df.empty:
        print("No expense transactions available.")
        return

    grouped = expense_df.groupby('Category')['Amount'].sum().reset_index()
    plt.figure(figsize=(10, 5))
    plt.bar(grouped['Category'], grouped['Amount'], color='tomato')
    plt.title('Expenses by Categories')
    plt.xlabel('Category')
    plt.ylabel('Total Amount')
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()


# 3. Income by Categories → Bar Chart
def income_by_categories():
    df = load_data()
    if df is None:
        return

    income_df = df[df['Expense/Income'] == 'Income']
    if income_df.empty:
        print("No income transactions available.")
        return

    grouped = income_df.groupby('Category')['Amount'].sum().reset_index()
    plt.figure(figsize=(10, 5))
    plt.bar(grouped['Category'], grouped['Amount'], color='gold')
    plt.title('Income by Categories')
    plt.xlabel('Category')
    plt.ylabel('Total Amount')
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()


# 4. Expense by Months → Line Chart
def expense_by_months():
    df = load_data()
    if df is None:
        return

    expense_df = df[df['Expense/Income'] == 'Expense']
    if expense_df.empty:
        print("No expense transactions available.")
        return

    expense_df['Month'] = expense_df['Date'].dt.to_period('M').astype(str)
    grouped = expense_df.groupby('Month')['Amount'].sum().reset_index()
    plt.figure(figsize=(10, 5))
    plt.plot(grouped['Month'], grouped['Amount'], marker='o', linestyle='-', color='red')
    plt.title('Monthly Expense Trend')
    plt.xlabel('Month')
    plt.ylabel('Total Expense')
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()


# 5. Income by Months → Line Chart
def income_by_months():
    df = load_data()
    if df is None:
        return

    income_df = df[df['Expense/Income'] == 'Income']
    if income_df.empty:
        print("No income transactions available.")
        return

    income_df['Month'] = income_df['Date'].dt.to_period('M').astype(str)
    grouped = income_df.groupby('Month')['Amount'].sum().reset_index()
    plt.figure(figsize=(10, 5))
    plt.plot(grouped['Month'], grouped['Amount'], marker='o', linestyle='-', color='green')
    plt.title('Monthly Income Trend')
    plt.xlabel('Month')
    plt.ylabel('Total Income')
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# #### MAIN FUNCTION

# %%
# Main function 

'''
Main functions to work on for now
1. Ask user what operation would they like to do
2. Operations users are allowed to do
    1. Make Transcations
        1. Income or Expense
    2. Display all the transcations
    3. Display only the expense transcations
    4. Display only the income transcations
    5. Display expense categories transactions
    6. Display income categoeis transcations
    7. Visualizations : 
        1. Income vs expense
        2. Expense by categories
        3. Expense by months
        4. Income by categories

    2,3,4,5,6 - Work with pandas
    7 - work with matplotlib
'''

# Balance Variable
balance = 10000

# Define available operations
operations = {
    1: "💸 Make a Transaction",
    2: "📜 Display All Transactions",
    3: "📉 Display Only Expense Transactions",
    4: "📈 Display Only Income Transactions",
    5: "📊 Display Expenses by Categories",
    6: "📂 Display Income by Categories",
    7: "📊 Generate Visualization Reports",
    8: "❓ Help (Operations List)",
    0: "🚪 Exit Application"
}

# Define visualization options
visualizations = {
    1: "📊 Income vs Expense",
    2: "📌 Expense by Categories",
    3: "📆 Expense by Months",
    4: "📂 Income by Categories",
    5: "📅 Income by Months"
}

# Function to display operations menu
def display_menu():
    print("\n" + "="*50)
    print(" 📌 EXPENSE TRACKER MENU ".center(50))
    print("="*50)
    for key, value in operations.items():
        print(f" {key}. {value}")
    print("="*50 + "\n")

# Function to display transaction options
def transaction_menu():
    print("\n" + "-"*40)
    print(" 🔄 TRANSACTION MENU ".center(40))
    print("-"*40)
    print(" 1. 💰 Income")
    print(" 2. 💸 Expense")
    print("-"*40)
    return int(input(" 👉 Choose a transaction type (1/2): "))

# Function to display visualization options
def visualization_menu():
    print("\n" + "-"*50)
    print(" 📊 VISUALIZATION OPTIONS ".center(50))
    print("-"*50)
    for key, value in visualizations.items():
        print(f" {key}. {value}")
    print("-"*50)
    return int(input(" 👉 Choose a visualization type: "))

# Main CLI Loop
while True:
    display_menu()
    try:
        user_input = int(input("👉 Select an option: "))

        if user_input == 1:
            user_choice = transaction_menu()
            if user_choice == 1:
                income()
            elif user_choice == 2:
                expenses()
            else:
                print("❌ Invalid choice! Please enter 1 or 2.")

        elif user_input == 2:
            transcations_list()
        elif user_input == 3:
            expense_transaction()
        elif user_input == 4:
            income_transaction()
        elif user_input == 5:
            expense_category_transactions()
        elif user_input == 6:
            income_category_transactions()
        elif user_input == 7:
            vis_choice = visualization_menu()
            if vis_choice == 1:
                income_vs_expense()
            elif vis_choice == 2:
                expense_by_categories()
            elif vis_choice == 3:
                expense_by_months()
            elif vis_choice == 4:
                income_by_categories()
            elif vis_choice == 5:
                income_by_months()
            else:
                print("❌ Invalid choice! Please enter a valid option.")


        elif user_input == 8:
            print("\n📌 Available Operations:")
            for key, value in operations.items():
                print(f" {key}. {value}")
            print()

        elif user_input == 0:
            print("\n🚀 Thank you for using the Expense Tracker! Goodbye! 👋\n")
            break

        else:
            print("\n❌ Access Denied! Invalid option. Please select from the menu.\n")

    except ValueError:
        print("\n❌ Invalid input! Please enter a number.\n")

    print()
# Out:
# ==================================================
#               📌 EXPENSE TRACKER MENU
# ==================================================
#  1. 💸 Make a Transaction
#  2. 📜 Display All Transactions
#  3. 📉 Display Only Expense Transactions
#  4. 📈 Display Only Income Transactions
#  5. 📊 Display Expenses by Categories
#  6. 📂 Display Income by Categories
#  7. 📊 Generate Visualization Reports
#  8. ❓ Help (Operations List)
#  0. 🚪 Exit Application
# ==================================================
#
#
# ===========================================================================
#                              📜 TRANSACTION LIST
# ===========================================================================
# Date                 | Type            | Category        | Payment Method       |     Amount |    Balance
# ---------------------------------------------------------------------------
# 2025-02-12 18:57:57  | Expense         | Food            | Cash                 |      200.0 |     9800.0
# 2025-02-12 18:58:08  | Income          | Salary          | Bank to Bank         |     1000.0 |    10800.0
# 2025-02-12 18:58:19  | Income          | Freelance       | Bank to Bank         |      250.0 |    11050.0
# 2025-02-12 18:58:42  | Expense         | Transport       | Cash                 |      250.0 |    10800.0
# 2025-02-12 18:59:06  | Expense         | Food            | UPI                  |      270.0 |    10530.0
# 2025-02-12 18:59:34  | Expense         | Food            | Cash                 |      100.0 |    10430.0
# 2025-02-13 17:39:14  | Expense         | Bills           | UPI                  |      650.0 |     9350.0
# 2025-02-13 17:39:21  | Income          | Gifts           | Bank to Bank         |     2560.0 |    11910.0
# 2023-12-01 02:30:13  | Income          | Investments     | Cash                 |    3870.56 |   15780.56
# 2023-01-15 17:58:17  | Expense         | Transport       | Bank to Bank         |    3162.77 |   12617.79
# 2023-07-22 11:22:01  | Expense         | Travel          | Credit Card          |     4569.9 |    8047.89
# 2024-01-04 20:26:14  | Expense         | Travel          | UPI                  |     473.67 |    7574.22
# 2023-03-11 20:29:25  | Income          | Investments     | Bank to Bank         |    4471.44 |   12045.66
# 2023-02-27 16:48:04  | Income          | Freelance       | Mobile Wallet        |    1158.43 |   13204.09
# 2023-04-02 13:02:51  | Income          | Rental Income   | Other                |    4031.48 |   17235.57
# 2023-10-11 07:17:00  | Expense         | Housing         | Credit Card          |    4237.84 |   12997.73
# 2023-01-29 14:17:04  | Expense         | Transport       | UPI                  |    3590.35 |    9407.38
# 2023-06-14 20:35:34  | Income          | Gifts           | Other                |     2558.1 |   11965.48
# 2023-06-01 19:23:33  | Expense         | Bills           | Bank to Bank         |     688.66 |   11276.82
# 2024-01-24 23:04:12  | Income          | Gifts           | Cash                 |    3472.09 |   14748.91
# 2023-06-18 11:54:51  | Income          | Freelance       | Other                |    3061.21 |   17810.12
# 2023-07-20 13:36:54  | Expense         | Entertainment   | Bank to Bank         |    1810.02 |    16000.1
# 2023-09-03 10:20:30  | Income          | Other           | Other                |    2988.51 |   18988.61
# 2023-08-28 07:53:37  | Expense         | Travel          | UPI                  |    3514.73 |   15473.88
# 2024-01-02 19:44:46  | Expense         | Education       | Mobile Wallet        |    2886.27 |   12587.61
# 2023-06-10 13:49:07  | Expense         | Travel          | Credit Card          |    2661.67 |    9925.94
# 2023-08-11 01:32:12  | Expense         | Housing         | Debit Card           |     823.11 |    9102.83
# 2023-07-21 16:01:52  | Income          | Gifts           | Debit Card           |    3322.99 |   12425.82
# 2024-02-04 15:56:32  | Income          | Other           | Debit Card           |    3050.81 |   15476.63
# 2023-11-16 08:04:01  | Expense         | Entertainment   | Debit Card           |    2482.85 |   12993.78
# 2023-05-23 04:54:06  | Expense         | Bills           | Bank to Bank         |    3636.01 |    9357.77
# 2023-03-04 20:26:16  | Income          | Investments     | Credit Card          |    2198.43 |    11556.2
# 2023-07-09 15:33:08  | Expense         | Entertainment   | Mobile Wallet        |    1186.01 |   10370.19
# 2023-01-07 00:55:29  | Income          | Business Income | UPI                  |     3292.2 |   13662.39
# 2024-01-23 16:49:02  | Income          | Salary          | Mobile Wallet        |     3434.1 |   17096.49
# 2023-03-21 15:08:48  | Income          | Gifts           | Bank to Bank         |     968.24 |   18064.73
# 2023-12-31 22:52:03  | Expense         | Shopping        | Mobile Wallet        |     1053.4 |   17011.33
# 2024-01-01 03:49:50  | Income          | Other           | Cash                 |    1107.63 |   18118.96
# 2023-08-08 14:35:37  | Income          | Salary          | UPI                  |    3382.68 |   21501.64
# 2024-01-06 20:52:58  | Income          | Investments     | Mobile Wallet        |    3918.77 |   25420.41
# 2023-10-09 14:30:52  | Expense         | Travel          | Debit Card           |    2988.93 |   22431.48
# 2023-11-06 18:17:59  | Expense         | Transport       | Debit Card           |     745.36 |   21686.12
# 2023-08-22 03:18:26  | Expense         | Bills           | Debit Card           |    2638.04 |   19048.08
# 2023-03-23 04:51:28  | Expense         | Travel          | Debit Card           |     479.95 |   18568.13
# 2023-04-12 03:20:49  | Income          | Gifts           | Mobile Wallet        |     355.92 |   18924.05
# 2023-04-02 23:09:52  | Income          | Other           | Mobile Wallet        |    4780.79 |   23704.84
# 2023-07-09 17:18:28  | Expense         | Education       | Credit Card          |    1753.34 |    21951.5
# 2023-05-01 18:09:25  | Income          | Salary          | Credit Card          |     124.37 |   22075.87
# 2023-10-01 01:00:43  | Income          | Other           | Cash                 |    4137.85 |   26213.72
# 2023-08-29 14:12:44  | Expense         | Travel          | Bank to Bank         |    4521.09 |   21692.63
# 2023-01-21 04:04:14  | Expense         | Shopping        | Other                |     1946.4 |   19746.23
# 2023-05-06 19:30:26  | Expense         | Travel          | Bank to Bank         |     3070.0 |   16676.23
# 2023-09-15 01:37:00  | Income          | Investments     | Other                |    3527.73 |   20203.96
# 2023-01-21 14:24:46  | Income          | Investments     | UPI                  |    3615.67 |   23819.63
# 2023-08-11 11:54:53  | Expense         | Transport       | Other                |    3975.48 |   19844.15
# 2023-07-08 07:05:17  | Expense         | Education       | Credit Card          |    1456.23 |   18387.92
# 2023-01-31 04:09:50  | Expense         | Education       | Cash                 |    4633.93 |   13753.99
# 2023-11-19 13:25:41  | Income          | Gifts           | Debit Card           |    2603.34 |   16357.33
# 2023-09-13 05:52:09  | Income          | Rental Income   | Other                |    3832.55 |   20189.88
# 2023-12-16 06:22:06  | Expense         | Transport       | Mobile Wallet        |    1460.69 |   18729.19
# 2023-10-04 15:58:24  | Income          | Business Income | UPI                  |    2912.03 |   21641.22
# 2023-10-15 07:39:32  | Income          | Gifts           | Bank to Bank         |     4124.0 |   25765.22
# 2023-08-26 23:38:18  | Income          | Other           | Debit Card           |    1777.18 |    27542.4
# 2024-01-05 06:01:25  | Expense         | Bills           | UPI                  |    1164.82 |   26377.58
# 2023-07-05 13:30:01  | Expense         | Food            | Debit Card           |    3601.14 |   22776.44
# 2023-12-30 12:24:14  | Expense         | Food            | Bank to Bank         |    3959.34 |    18817.1
# 2024-01-12 22:55:09  | Income          | Salary          | Cash                 |    1760.65 |   20577.75
# 2023-09-17 00:16:59  | Income          | Rental Income   | Debit Card           |    4816.32 |   25394.07
# 2023-11-17 07:00:11  | Expense         | Miscellaneous   | Mobile Wallet        |    4445.35 |   20948.72
# 2023-08-01 19:08:05  | Income          | Salary          | Debit Card           |    2326.73 |   23275.45
# 2023-03-21 23:46:35  | Income          | Rental Income   | Bank to Bank         |     4447.5 |   27722.95
# 2023-01-09 12:50:20  | Expense         | Entertainment   | Other                |     3981.9 |   23741.05
# 2023-08-06 16:23:30  | Income          | Rental Income   | Other                |    3097.45 |    26838.5
# 2023-04-21 15:29:25  | Expense         | Entertainment   | Other                |    4206.64 |   22631.86
# 2023-03-25 23:20:16  | Income          | Business Income | Cash                 |    4968.61 |   27600.47
# 2023-05-02 09:56:49  | Income          | Other           | Other                |     3258.3 |   30858.77
# 2023-09-18 02:34:14  | Expense         | Travel          | Other                |    4212.36 |   26646.41
# 2023-11-02 21:29:18  | Expense         | Education       | Cash                 |     419.95 |   26226.46
# 2023-11-02 12:24:48  | Expense         | Food            | Cash                 |    1226.14 |   25000.32
# 2023-02-26 12:43:02  | Income          | Gifts           | UPI                  |    4206.38 |    29206.7
# 2023-08-17 00:06:31  | Income          | Rental Income   | Bank to Bank         |    4909.82 |   34116.52
# 2023-12-25 00:57:16  | Expense         | Shopping        | Other                |     940.48 |   33176.04
# 2024-01-27 19:53:44  | Expense         | Bills           | Mobile Wallet        |     4053.5 |   29122.54
# 2023-09-01 22:38:52  | Expense         | Food            | Debit Card           |     776.37 |   28346.17
# 2023-02-16 08:11:09  | Expense         | Shopping        | Cash                 |     937.86 |   27408.31
# 2023-05-16 13:22:13  | Expense         | Travel          | Bank to Bank         |      686.9 |   26721.41
# 2023-07-06 11:33:23  | Expense         | Miscellaneous   | Debit Card           |     4444.6 |   22276.81
# 2023-03-18 04:49:45  | Expense         | Transport       | Mobile Wallet        |    2381.01 |    19895.8
# 2023-12-16 11:00:15  | Expense         | Bills           | Cash                 |    1600.97 |   18294.83
# 2023-05-25 03:02:35  | Income          | Rental Income   | Cash                 |     4626.9 |   22921.73
# 2023-01-06 16:45:59  | Expense         | Bills           | Bank to Bank         |     4120.8 |   18800.93
# 2023-10-04 01:12:59  | Expense         | Housing         | UPI                  |    1532.15 |   17268.78
# 2023-11-24 21:57:18  | Expense         | Housing         | Credit Card          |    4940.87 |   12327.91
# 2023-06-11 16:34:09  | Expense         | Transport       | UPI                  |    3198.77 |    9129.14
# 2023-08-30 15:55:55  | Expense         | Transport       | Credit Card          |    3587.56 |    5541.58
# 2023-06-29 05:58:34  | Expense         | Transport       | UPI                  |    4242.78 |     1298.8
# 2023-09-10 03:20:36  | Income          | Freelance       | Mobile Wallet        |    1312.56 |    2611.36
# 2024-01-05 12:42:20  | Expense         | Transport       | Mobile Wallet        |    3128.23 |    -516.87
# 2023-12-07 03:20:57  | Income          | Rental Income   | Credit Card          |     365.08 |    -151.79
# 2024-01-05 16:17:38  | Expense         | Shopping        | Cash                 |     540.93 |    -692.72
# 2023-01-25 10:26:46  | Expense         | Health          | Cash                 |     454.28 |    -1147.0
# 2023-03-25 06:41:49  | Income          | Freelance       | Credit Card          |    3176.27 |    2029.27
# 2024-01-30 21:54:25  | Income          | Rental Income   | Other                |    3575.96 |    5605.23
# 2023-08-28 09:16:38  | Expense         | Miscellaneous   | Debit Card           |    1126.44 |    4478.79
# 2023-08-04 04:07:21  | Expense         | Housing         | Cash                 |    1481.44 |    2997.35
# 2023-03-06 20:40:48  | Income          | Rental Income   | Mobile Wallet        |    1771.32 |    4768.67
# 2023-03-03 19:10:27  | Expense         | Transport       | Cash                 |    3276.23 |    1492.44
# 2023-11-29 12:20:49  | Expense         | Health          | UPI                  |    4342.26 |   -2849.82
# 2023-09-08 11:35:37  | Expense         | Health          | Cash                 |    4244.19 |   -7094.01
# 2023-10-01 18:41:01  | Expense         | Bills           | Other                |    3217.58 |  -10311.59
# 2023-06-05 03:42:28  | Expense         | Bills           | Cash                 |    4637.64 |  -14949.23
# 2023-06-08 15:53:19  | Expense         | Transport       | Credit Card          |    1910.91 |  -16860.14
# 2023-04-14 11:43:43  | Expense         | Transport       | Bank to Bank         |     914.72 |  -17774.86
# 2023-09-09 09:20:04  | Income          | Investments     | Bank to Bank         |    3288.89 |  -14485.97
# 2023-09-27 23:45:16  | Expense         | Bills           | Debit Card           |     636.81 |  -15122.78
# 2023-05-02 04:03:07  | Expense         | Housing         | UPI                  |    1282.17 |  -16404.95
# 2023-04-06 21:27:24  | Expense         | Bills           | Debit Card           |    1324.32 |  -17729.27
# 2023-09-01 22:34:27  | Expense         | Miscellaneous   | UPI                  |    4778.87 |  -22508.14
# 2023-03-09 01:21:58  | Income          | Other           | Bank to Bank         |     2796.5 |  -19711.64
# 2023-01-08 16:23:49  | Expense         | Health          | UPI                  |    3995.62 |  -23707.26
# 2023-11-07 09:52:54  | Expense         | Miscellaneous   | UPI                  |    4502.83 |  -28210.09
# 2023-07-29 03:00:23  | Income          | Other           | Mobile Wallet        |    3714.87 |  -24495.22
# 2023-12-05 12:25:56  | Income          | Investments     | Bank to Bank         |    1844.22 |   -22651.0
# 2023-07-29 22:01:58  | Income          | Rental Income   | Other                |    2003.89 |  -20647.11
# 2023-12-15 19:37:11  | Income          | Other           | Bank to Bank         |    4281.82 |  -16365.29
# 2023-02-20 01:16:49  | Expense         | Shopping        | Credit Card          |     952.64 |  -17317.93
# 2023-05-02 05:39:23  | Income          | Salary          | Credit Card          |    2814.69 |  -14503.24
# 2023-08-10 10:10:00  | Income          | Salary          | Other                |    4251.35 |  -10251.89
# 2023-12-12 20:51:30  | Expense         | Health          | Mobile Wallet        |    3853.61 |   -14105.5
# 2023-03-28 15:52:22  | Expense         | Health          | Mobile Wallet        |    3531.53 |  -17637.03
# 2023-08-02 01:40:50  | Income          | Investments     | Cash                 |     2170.1 |  -15466.93
# 2023-11-16 18:16:51  | Income          | Other           | Cash                 |    2848.01 |  -12618.92
# 2023-11-10 15:56:38  | Expense         | Housing         | Credit Card          |    1685.88 |   -14304.8
# 2023-10-07 19:54:16  | Income          | Gifts           | Cash                 |    1001.59 |  -13303.21
# 2023-03-17 22:42:00  | Expense         | Education       | Cash                 |     770.35 |  -14073.56
# 2023-07-24 20:09:06  | Expense         | Food            | Cash                 |    1490.36 |  -15563.92
# 2024-01-27 03:48:29  | Income          | Gifts           | Bank to Bank         |    2823.44 |  -12740.48
# 2023-07-23 09:16:29  | Income          | Investments     | UPI                  |    2275.86 |  -10464.62
# 2024-01-31 02:35:12  | Income          | Rental Income   | Other                |    3604.58 |   -6860.04
# 2023-01-02 20:27:42  | Income          | Investments     | Debit Card           |    1277.27 |   -5582.77
# 2023-06-02 22:09:11  | Income          | Investments     | Credit Card          |     298.94 |   -5283.83
# 2023-08-03 22:00:56  | Income          | Rental Income   | Debit Card           |    4914.18 |    -369.65
# 2023-11-01 09:23:56  | Income          | Salary          | Credit Card          |    3171.41 |    2801.76
# 2023-09-29 21:37:09  | Expense         | Shopping        | UPI                  |    3078.69 |    -276.93
# 2023-09-07 07:02:18  | Income          | Salary          | Mobile Wallet        |    1077.08 |     800.15
# 2023-07-25 01:34:30  | Expense         | Bills           | UPI                  |    3072.05 |    -2271.9
# 2023-06-13 00:43:24  | Expense         | Housing         | UPI                  |    1912.08 |   -4183.98
# 2023-09-07 08:43:00  | Income          | Gifts           | Bank to Bank         |    3010.64 |   -1173.34
# 2023-02-23 12:54:06  | Income          | Gifts           | Other                |    1604.06 |     430.72
# 2023-01-10 01:01:48  | Expense         | Travel          | Cash                 |     1683.3 |   -1252.58
# 2023-01-03 09:18:09  | Expense         | Education       | UPI                  |    4628.87 |   -5881.45
# 2023-04-26 09:50:08  | Expense         | Transport       | Cash                 |    2759.54 |   -8640.99
# 2023-04-19 19:09:45  | Income          | Salary          | UPI                  |    2073.42 |   -6567.57
# 2023-05-11 19:19:54  | Income          | Freelance       | Debit Card           |    2454.68 |   -4112.89
# 2023-11-24 01:06:38  | Expense         | Travel          | Cash                 |     216.91 |    -4329.8
# 2023-06-22 09:28:23  | Expense         | Education       | Mobile Wallet        |      811.2 |    -5141.0
# 2023-09-20 12:38:11  | Expense         | Housing         | Debit Card           |    4213.74 |   -9354.74
# 2024-01-25 00:46:33  | Income          | Other           | Other                |    3459.69 |   -5895.05
# 2023-10-19 10:44:04  | Expense         | Education       | Bank to Bank         |    4229.89 |  -10124.94
# 2023-02-01 07:17:39  | Expense         | Shopping        | Mobile Wallet        |    4540.59 |  -14665.53
# 2023-07-30 21:39:35  | Expense         | Bills           | Credit Card          |    2106.35 |  -16771.88
# 2023-05-03 19:32:47  | Expense         | Food            | Other                |     3643.8 |  -20415.68
# 2023-10-12 22:49:36  | Expense         | Travel          | Cash                 |    3386.76 |  -23802.44
# 2023-08-12 07:12:01  | Expense         | Travel          | Mobile Wallet        |    4542.11 |  -28344.55
# 2024-01-31 12:55:55  | Expense         | Transport       | Other                |    2185.75 |   -30530.3
# 2023-02-13 03:53:23  | Expense         | Entertainment   | Cash                 |    3701.53 |  -34231.83
# 2023-04-13 14:00:22  | Expense         | Housing         | Other                |    1770.33 |  -36002.16
# 2023-09-21 21:17:11  | Expense         | Food            | Debit Card           |    2379.22 |  -38381.38
# 2023-09-30 20:51:17  | Expense         | Education       | UPI                  |    4091.38 |  -42472.76
# 2023-02-10 08:58:23  | Income          | Gifts           | Mobile Wallet        |    3431.09 |  -39041.67
# 2023-12-06 02:37:29  | Expense         | Health          | Other                |     1790.7 |  -40832.37
# 2023-07-03 03:12:18  | Expense         | Travel          | Other                |     267.47 |  -41099.84
# 2023-05-14 17:48:26  | Expense         | Housing         | Bank to Bank         |     4685.8 |  -45785.64
# 2023-12-20 19:12:31  | Expense         | Miscellaneous   | Debit Card           |    4867.87 |  -50653.51
# 2023-02-21 12:09:36  | Income          | Other           | Mobile Wallet        |     586.67 |  -50066.84
# 2023-07-07 02:16:49  | Income          | Other           | Credit Card          |     3829.1 |  -46237.74
# 2023-07-22 07:32:56  | Expense         | Miscellaneous   | Bank to Bank         |    2233.38 |  -48471.12
# 2023-05-09 14:05:20  | Income          | Gifts           | Credit Card          |     987.59 |  -47483.53
# 2023-07-27 00:21:05  | Income          | Gifts           | Other                |     547.01 |  -46936.52
# 2023-01-14 01:19:34  | Income          | Gifts           | Bank to Bank         |    2105.81 |  -44830.71
# 2023-06-26 11:51:34  | Income          | Salary          | Debit Card           |    4813.06 |  -40017.65
# 2023-08-04 21:00:58  | Expense         | Food            | Debit Card           |     515.26 |  -40532.91
# 2023-11-13 14:32:02  | Income          | Salary          | Other                |    1989.21 |   -38543.7
# 2023-02-14 21:29:04  | Expense         | Transport       | Mobile Wallet        |    1974.26 |  -40517.96
# 2023-10-29 10:05:57  | Expense         | Entertainment   | Other                |     181.43 |  -40699.39
# 2023-05-12 18:23:24  | Expense         | Food            | Debit Card           |    3177.57 |  -43876.96
# 2023-03-10 02:27:41  | Income          | Investments     | Other                |    3046.12 |  -40830.84
# 2023-06-10 23:51:33  | Expense         | Health          | UPI                  |    4242.83 |  -45073.67
# 2024-01-07 12:22:18  | Expense         | Entertainment   | Debit Card           |    2894.27 |  -47967.94
# 2023-02-18 01:12:20  | Income          | Gifts           | Credit Card          |    4160.55 |  -43807.39
# 2023-04-10 09:15:30  | Income          | Gifts           | UPI                  |    1807.31 |  -42000.08
# 2023-12-05 21:10:45  | Income          | Rental Income   | UPI                  |    1898.42 |  -40101.66
# 2023-01-22 08:35:23  | Expense         | Health          | UPI                  |      880.3 |  -40981.96
# 2023-10-15 16:35:35  | Income          | Salary          | Credit Card          |     914.53 |  -40067.43
# 2023-05-16 23:34:36  | Income          | Salary          | Credit Card          |     714.85 |  -39352.58
# 2023-08-09 20:27:30  | Expense         | Food            | Credit Card          |    2925.76 |  -42278.34
# 2023-10-29 20:47:48  | Income          | Rental Income   | UPI                  |    2112.57 |  -40165.77
# 2024-01-05 07:46:06  | Expense         | Shopping        | UPI                  |    1152.97 |  -41318.74
# 2023-07-20 22:10:30  | Income          | Rental Income   | UPI                  |     2842.3 |  -38476.44
# 2024-01-21 23:46:27  | Expense         | Travel          | Cash                 |    3111.55 |  -41587.99
# 2023-02-26 10:50:16  | Income          | Gifts           | Bank to Bank         |    3417.57 |  -38170.42
# 2023-09-18 10:49:51  | Income          | Freelance       | Credit Card          |    1913.09 |  -36257.33
# 2023-06-03 08:28:00  | Expense         | Bills           | Mobile Wallet        |     401.06 |  -36658.39
# 2023-04-06 15:46:44  | Expense         | Education       | Debit Card           |    1147.49 |  -37805.88
# 2023-05-10 14:00:38  | Expense         | Food            | Other                |    1458.14 |  -39264.02
# 2023-12-10 16:23:22  | Expense         | Housing         | Mobile Wallet        |    1121.65 |  -40385.67
# 2023-10-27 13:11:30  | Expense         | Shopping        | Debit Card           |    1121.33 |   -41507.0
# 2024-01-26 15:30:21  | Expense         | Bills           | Mobile Wallet        |    4843.59 |  -46350.59
# 2023-04-08 17:04:22  | Income          | Investments     | Bank to Bank         |     768.84 |  -45581.75
# 2023-02-08 16:50:10  | Expense         | Food            | Cash                 |    2950.22 |  -48531.97
# 2023-02-15 08:24:32  | Expense         | Bills           | Other                |     1556.3 |  -50088.27
# 2023-01-19 19:26:41  | Income          | Freelance       | Cash                 |    1431.24 |  -48657.03
# 2023-02-13 20:03:20  | Income          | Other           | Debit Card           |    1154.18 |  -47502.85
# 2023-12-20 14:39:20  | Expense         | Transport       | Cash                 |    4328.12 |  -51830.97
# 2023-10-10 20:37:53  | Income          | Salary          | Credit Card          |    3751.78 |  -48079.19
# 2023-02-09 19:16:14  | Expense         | Food            | UPI                  |    4677.57 |  -52756.76
# 2023-08-06 11:15:49  | Expense         | Food            | Mobile Wallet        |    2075.24 |   -54832.0
# 2023-05-31 10:01:34  | Expense         | Miscellaneous   | UPI                  |    4469.12 |  -59301.12
# 2023-10-18 00:06:57  | Expense         | Transport       | Bank to Bank         |     1140.0 |  -60441.12
# 2023-05-28 05:10:40  | Income          | Gifts           | Debit Card           |      493.3 |  -59947.82
# 2023-11-13 16:34:44  | Income          | Gifts           | Cash                 |    2704.26 |  -57243.56
# 2023-05-13 14:33:09  | Income          | Freelance       | Debit Card           |    3447.48 |  -53796.08
# 2023-05-21 03:21:17  | Expense         | Travel          | Mobile Wallet        |    1186.66 |  -54982.74
# 2023-12-14 02:23:59  | Expense         | Education       | Cash                 |    3349.62 |  -58332.36
# 2023-02-23 09:47:58  | Expense         | Shopping        | Bank to Bank         |     345.98 |  -58678.34
# 2023-03-01 06:27:47  | Expense         | Food            | Cash                 |    4831.91 |  -63510.25
# 2023-05-25 19:40:55  | Income          | Gifts           | UPI                  |    1294.79 |  -62215.46
# 2023-09-04 13:37:44  | Income          | Gifts           | Mobile Wallet        |      970.2 |  -61245.26
# 2023-06-12 14:07:50  | Expense         | Health          | Cash                 |     1549.4 |  -62794.66
# 2023-08-06 15:07:27  | Income          | Salary          | Cash                 |     4709.3 |  -58085.36
# 2024-01-12 13:21:01  | Expense         | Housing         | Cash                 |    4820.76 |  -62906.12
# 2023-01-08 19:04:39  | Expense         | Health          | Mobile Wallet        |    4639.65 |  -67545.77
# 2023-03-30 05:57:25  | Expense         | Miscellaneous   | Cash                 |     1390.8 |  -68936.57
# 2023-05-01 09:56:37  | Income          | Freelance       | Debit Card           |    4426.27 |   -64510.3
# 2023-03-07 13:09:54  | Income          | Other           | UPI                  |    3666.01 |  -60844.29
# 2023-06-29 03:58:13  | Income          | Investments     | UPI                  |    1462.06 |  -59382.23
# 2023-02-04 06:48:33  | Income          | Investments     | Bank to Bank         |    3262.23 |   -56120.0
# 2023-09-07 22:06:36  | Income          | Rental Income   | Debit Card           |    1443.28 |  -54676.72
# 2023-02-09 20:57:13  | Expense         | Food            | Debit Card           |    2586.63 |  -57263.35
# 2023-02-14 13:48:48  | Income          | Gifts           | Cash                 |    3622.82 |  -53640.53
# 2023-04-13 18:56:08  | Income          | Freelance       | UPI                  |    2194.41 |  -51446.12
# 2023-04-28 22:05:53  | Income          | Investments     | Cash                 |    1456.68 |  -49989.44
# 2023-08-24 13:56:38  | Expense         | Travel          | Cash                 |    1274.71 |  -51264.15
# 2023-01-17 09:47:20  | Expense         | Education       | Credit Card          |    3614.03 |  -54878.18
# 2023-04-29 03:50:55  | Expense         | Housing         | Credit Card          |     560.17 |  -55438.35
# 2023-10-09 04:56:31  | Expense         | Shopping        | Mobile Wallet        |     300.86 |  -55739.21
# 2023-11-07 08:15:00  | Expense         | Food            | Credit Card          |      728.7 |  -56467.91
# 2023-01-25 18:45:18  | Expense         | Health          | Other                |     319.08 |  -56786.99
# 2023-03-30 21:13:51  | Income          | Gifts           | Credit Card          |    2495.55 |  -54291.44
# 2023-09-28 03:46:25  | Expense         | Transport       | Debit Card           |    1943.39 |  -56234.83
# 2023-07-24 16:01:34  | Expense         | Bills           | Bank to Bank         |     1463.4 |  -57698.23
# 2023-08-07 15:01:37  | Income          | Rental Income   | Credit Card          |    4329.27 |  -53368.96
# 2023-03-11 10:51:15  | Income          | Freelance       | Cash                 |    3896.17 |  -49472.79
# 2023-05-04 10:01:21  | Income          | Salary          | Bank to Bank         |    4929.93 |  -44542.86
# 2023-04-17 13:21:12  | Income          | Freelance       | Mobile Wallet        |     757.22 |  -43785.64
# 2023-11-21 07:38:27  | Income          | Rental Income   | Cash                 |    2889.56 |  -40896.08
# 2023-03-02 06:43:17  | Expense         | Housing         | Bank to Bank         |    4853.21 |  -45749.29
# 2023-03-06 21:25:43  | Income          | Other           | Credit Card          |    3356.56 |  -42392.73
# 2023-03-29 18:52:43  | Expense         | Food            | Mobile Wallet        |    2249.36 |  -44642.09
# 2023-05-18 09:54:05  | Expense         | Food            | Other                |    1905.41 |   -46547.5
# 2023-09-30 09:17:00  | Expense         | Entertainment   | Debit Card           |    2831.39 |  -49378.89
# 2023-02-28 07:25:15  | Income          | Rental Income   | Bank to Bank         |     970.19 |   -48408.7
# 2023-09-09 13:31:37  | Income          | Other           | Credit Card          |     957.84 |  -47450.86
# 2023-01-25 19:03:56  | Expense         | Miscellaneous   | Bank to Bank         |     670.17 |  -48121.03
# 2023-03-29 17:20:41  | Expense         | Food            | UPI                  |     355.92 |  -48476.95
# 2023-11-05 06:40:34  | Expense         | Miscellaneous   | Credit Card          |    4552.12 |  -53029.07
# 2023-11-13 09:53:51  | Income          | Freelance       | UPI                  |    4568.36 |  -48460.71
# 2023-12-18 19:20:14  | Expense         | Education       | UPI                  |     311.59 |   -48772.3
# 2023-02-21 11:03:17  | Income          | Gifts           | Mobile Wallet        |    1164.24 |  -47608.06
# 2023-10-25 06:46:39  | Income          | Gifts           | Credit Card          |    3901.99 |  -43706.07
# 2023-07-06 09:33:24  | Income          | Other           | Bank to Bank         |    4421.73 |  -39284.34
# 2023-08-27 08:06:16  | Income          | Gifts           | Bank to Bank         |     603.96 |  -38680.38
# 2023-10-15 14:17:23  | Expense         | Education       | UPI                  |     4319.5 |  -42999.88
# 2023-12-29 08:33:50  | Income          | Other           | Debit Card           |    4836.63 |  -38163.25
# 2023-11-18 17:44:25  | Income          | Other           | Mobile Wallet        |    2263.98 |  -35899.27
# 2023-01-05 17:37:11  | Income          | Business Income | Mobile Wallet        |    2429.81 |  -33469.46
# 2023-07-02 01:50:14  | Expense         | Health          | Credit Card          |     2561.0 |  -36030.46
# 2023-11-17 07:04:20  | Income          | Other           | Mobile Wallet        |    1229.25 |  -34801.21
# 2023-01-20 05:15:49  | Expense         | Housing         | Bank to Bank         |    2115.97 |  -36917.18
# 2023-10-12 05:03:08  | Expense         | Housing         | Other                |     600.79 |  -37517.97
# 2023-10-17 01:38:05  | Income          | Rental Income   | Credit Card          |    1006.59 |  -36511.38
# 2023-09-29 20:49:48  | Expense         | Housing         | Other                |    1142.46 |  -37653.84
# 2024-01-07 09:43:28  | Income          | Other           | Debit Card           |    3972.78 |  -33681.06
# 2024-01-26 03:26:50  | Expense         | Shopping        | UPI                  |    2865.81 |  -36546.87
# 2023-11-01 23:09:00  | Expense         | Food            | UPI                  |    2748.22 |  -39295.09
# 2023-11-24 22:47:15  | Income          | Salary          | UPI                  |    2540.51 |  -36754.58
# 2023-01-02 02:28:36  | Income          | Gifts           | Cash                 |    3716.81 |  -33037.77
# 2023-02-23 14:39:12  | Income          | Rental Income   | Other                |    1715.02 |  -31322.75
# 2023-06-04 13:40:16  | Expense         | Health          | Debit Card           |    1193.72 |  -32516.47
# 2023-08-19 03:55:36  | Income          | Rental Income   | Bank to Bank         |    1507.87 |   -31008.6
# 2023-05-18 07:09:20  | Expense         | Food            | Debit Card           |    3450.81 |  -34459.41
# 2023-02-05 13:45:54  | Income          | Salary          | Cash                 |    1354.52 |  -33104.89
# 2023-01-31 22:11:32  | Income          | Salary          | Bank to Bank         |    2100.37 |  -31004.52
# 2023-06-25 12:10:56  | Income          | Freelance       | Mobile Wallet        |    4956.63 |  -26047.89
# 2024-02-05 03:46:34  | Expense         | Housing         | Bank to Bank         |    2268.74 |  -28316.63
# 2023-12-10 14:22:30  | Income          | Investments     | Bank to Bank         |    1098.72 |  -27217.91
# 2023-02-22 07:35:06  | Expense         | Bills           | Credit Card          |     3009.4 |  -30227.31
# 2023-10-18 01:55:57  | Income          | Investments     | Mobile Wallet        |    1006.17 |  -29221.14
# 2023-01-02 10:09:01  | Expense         | Miscellaneous   | Bank to Bank         |    3951.76 |   -33172.9
# 2023-04-14 16:30:40  | Expense         | Health          | Debit Card           |     461.81 |  -33634.71
# 2023-07-07 02:33:10  | Income          | Salary          | Credit Card          |    3500.81 |   -30133.9
# 2023-02-28 21:21:40  | Income          | Business Income | Cash                 |    1376.02 |  -28757.88
# 2023-11-12 00:23:45  | Income          | Freelance       | Bank to Bank         |    4862.85 |  -23895.03
# 2023-10-17 16:32:59  | Income          | Freelance       | Cash                 |    1365.73 |   -22529.3
# 2023-10-15 06:30:23  | Expense         | Housing         | UPI                  |    3150.28 |  -25679.58
# 2024-02-01 07:09:40  | Expense         | Transport       | Cash                 |    4032.86 |  -29712.44
# 2024-01-25 09:36:58  | Expense         | Health          | UPI                  |    2538.96 |   -32251.4
# 2023-06-02 03:12:18  | Income          | Freelance       | Bank to Bank         |    3467.77 |  -28783.63
# 2023-11-03 22:05:35  | Income          | Other           | UPI                  |    1334.23 |   -27449.4
# 2023-01-19 15:28:07  | Income          | Salary          | Credit Card          |     910.23 |  -26539.17
# 2023-03-06 00:28:49  | Expense         | Housing         | Credit Card          |    2353.07 |  -28892.24
# 2023-03-07 20:27:11  | Expense         | Entertainment   | Other                |    1800.09 |  -30692.33
# 2023-07-12 01:38:39  | Income          | Business Income | Mobile Wallet        |     3365.1 |  -27327.23
# 2023-12-02 18:43:33  | Expense         | Bills           | Credit Card          |    1922.53 |  -29249.76
# 2024-01-19 14:06:14  | Income          | Salary          | Other                |    2398.75 |  -26851.01
# 2023-09-07 03:43:02  | Income          | Investments     | UPI                  |    4712.11 |   -22138.9
# 2023-05-26 18:30:46  | Income          | Salary          | Debit Card           |     824.66 |  -21314.24
# 2023-12-28 19:50:47  | Expense         | Housing         | UPI                  |     747.83 |  -22062.07
# 2023-08-08 23:00:49  | Income          | Other           | Other                |    2759.39 |  -19302.68
# 2023-03-17 22:47:23  | Income          | Freelance       | UPI                  |    1457.12 |  -17845.56
# 2023-09-24 04:47:04  | Income          | Business Income | Bank to Bank         |    2419.04 |  -15426.52
# 2023-09-14 05:53:31  | Expense         | Entertainment   | UPI                  |     3741.2 |  -19167.72
# 2024-01-06 16:40:56  | Expense         | Food            | UPI                  |    3233.31 |  -22401.03
# 2023-06-10 22:30:40  | Expense         | Housing         | Credit Card          |    3160.06 |  -25561.09
# 2023-01-30 18:22:33  | Expense         | Miscellaneous   | Mobile Wallet        |      380.3 |  -25941.39
# 2023-05-15 11:32:41  | Income          | Salary          | Bank to Bank         |    3118.53 |  -22822.86
# 2023-06-13 01:08:44  | Expense         | Education       | Other                |    1674.06 |  -24496.92
# 2023-05-12 20:10:19  | Expense         | Health          | Cash                 |    4510.97 |  -29007.89
# 2023-01-23 18:23:27  | Income          | Other           | Credit Card          |    4995.16 |  -24012.73
# 2023-01-13 13:45:45  | Expense         | Health          | Other                |    2361.04 |  -26373.77
# 2023-11-28 05:21:57  | Expense         | Entertainment   | UPI                  |     383.53 |   -26757.3
# 2023-06-06 21:44:24  | Expense         | Travel          | UPI                  |    1719.37 |  -28476.67
# 2023-02-25 10:23:20  | Expense         | Education       | Bank to Bank         |    2518.17 |  -30994.84
# 2023-05-20 12:11:48  | Income          | Gifts           | Cash                 |     693.65 |  -30301.19
# 2023-06-26 06:04:33  | Expense         | Housing         | Bank to Bank         |    3630.37 |  -33931.56
# 2023-10-18 07:53:29  | Expense         | Housing         | Cash                 |    4825.17 |  -38756.73
# 2023-08-11 12:11:49  | Expense         | Education       | UPI                  |     853.88 |  -39610.61
# 2023-04-14 17:09:21  | Expense         | Food            | Mobile Wallet        |    2484.97 |  -42095.58
# 2023-05-02 03:17:52  | Income          | Gifts           | UPI                  |    1171.85 |  -40923.73
# 2023-12-16 22:38:12  | Expense         | Health          | Debit Card           |    2252.11 |  -43175.84
# 2023-12-18 02:27:44  | Income          | Gifts           | Debit Card           |    3182.96 |  -39992.88
# 2023-02-22 03:28:48  | Expense         | Health          | Bank to Bank         |    4182.67 |  -44175.55
# 2023-08-05 16:56:16  | Expense         | Travel          | UPI                  |    2979.94 |  -47155.49
# 2023-12-20 05:23:28  | Income          | Business Income | Mobile Wallet        |    1349.94 |  -45805.55
# 2023-11-22 16:26:27  | Expense         | Transport       | Bank to Bank         |     704.18 |  -46509.73
# 2023-05-07 22:01:38  | Expense         | Shopping        | Mobile Wallet        |    2371.86 |  -48881.59
# 2023-10-19 15:29:54  | Income          | Freelance       | Bank to Bank         |    1690.88 |  -47190.71
# 2023-11-01 10:23:43  | Income          | Gifts           | UPI                  |    2504.74 |  -44685.97
# 2023-06-19 22:02:37  | Income          | Rental Income   | Mobile Wallet        |     787.62 |  -43898.35
# 2023-09-15 15:38:16  | Expense         | Food            | Debit Card           |    3774.25 |   -47672.6
# 2023-10-18 05:10:13  | Income          | Salary          | Bank to Bank         |    3403.34 |  -44269.26
# 2023-01-24 01:02:30  | Expense         | Travel          | Credit Card          |     801.39 |  -45070.65
# 2023-09-11 04:30:06  | Income          | Investments     | Debit Card           |    3599.82 |  -41470.83
# 2023-12-08 22:16:15  | Income          | Other           | Bank to Bank         |     4884.5 |  -36586.33
# 2023-06-29 14:41:23  | Income          | Investments     | Credit Card          |    4698.56 |  -31887.77
# 2023-07-09 03:30:09  | Expense         | Miscellaneous   | Mobile Wallet        |    3965.53 |   -35853.3
# 2023-08-15 19:32:34  | Income          | Business Income | Other                |    4902.83 |  -30950.47
# 2023-04-15 13:13:25  | Expense         | Shopping        | Mobile Wallet        |    1831.29 |  -32781.76
# 2023-06-11 23:50:52  | Income          | Freelance       | Other                |    2737.23 |  -30044.53
# 2023-11-29 22:02:19  | Income          | Investments     | UPI                  |     2879.5 |  -27165.03
# 2023-12-19 00:44:43  | Income          | Gifts           | Cash                 |    2491.32 |  -24673.71
# 2023-12-16 06:57:24  | Expense         | Health          | Bank to Bank         |     536.98 |  -25210.69
# 2023-02-02 17:32:29  | Expense         | Miscellaneous   | Cash                 |    4004.71 |   -29215.4
# 2023-04-27 02:40:46  | Expense         | Travel          | Other                |    2683.13 |  -31898.53
# 2023-05-14 00:18:19  | Income          | Business Income | UPI                  |     467.52 |  -31431.01
# 2023-05-04 15:31:26  | Expense         | Shopping        | Cash                 |    3745.64 |  -35176.65
# 2023-11-13 09:52:48  | Income          | Business Income | Cash                 |     393.45 |   -34783.2
# 2023-04-18 00:00:48  | Income          | Gifts           | Cash                 |    1515.97 |  -33267.23
# 2023-03-20 01:02:24  | Income          | Salary          | Credit Card          |    4315.49 |  -28951.74
# 2023-12-30 12:23:01  | Income          | Business Income | Bank to Bank         |    4174.36 |  -24777.38
# 2023-03-21 09:47:25  | Income          | Freelance       | Debit Card           |     968.75 |  -23808.63
# 2023-09-14 06:28:21  | Expense         | Shopping        | Mobile Wallet        |    1380.69 |  -25189.32
# 2024-01-24 18:13:27  | Income          | Salary          | Debit Card           |    3228.99 |  -21960.33
# 2023-04-27 12:51:00  | Expense         | Shopping        | Bank to Bank         |     2024.4 |  -23984.73
# 2024-01-15 12:32:11  | Income          | Salary          | Other                |     942.28 |  -23042.45
# 2023-01-01 15:20:58  | Expense         | Shopping        | Other                |    3535.14 |  -26577.59
# 2023-08-26 08:57:01  | Expense         | Travel          | Debit Card           |    2780.67 |  -29358.26
# 2023-09-21 19:35:00  | Income          | Gifts           | Debit Card           |     260.78 |  -29097.48
# 2023-05-28 17:20:34  | Expense         | Health          | Bank to Bank         |    2398.85 |  -31496.33
# 2023-12-27 18:29:28  | Income          | Salary          | Credit Card          |    2210.12 |  -29286.21
# 2023-02-19 02:11:56  | Income          | Gifts           | Cash                 |    1438.89 |  -27847.32
# 2023-01-08 08:35:45  | Expense         | Travel          | UPI                  |    1777.69 |  -29625.01
# 2023-05-26 06:39:56  | Income          | Other           | Other                |    2674.58 |  -26950.43
# 2024-02-04 19:57:20  | Expense         | Bills           | Cash                 |    2513.68 |  -29464.11
# 2023-07-03 20:07:41  | Income          | Business Income | Other                |    2142.59 |  -27321.52
# 2023-01-04 05:05:20  | Expense         | Shopping        | Cash                 |     4212.7 |  -31534.22
# 2024-01-15 06:23:56  | Income          | Investments     | Bank to Bank         |    3039.57 |  -28494.65
# 2023-04-26 16:24:27  | Income          | Rental Income   | UPI                  |    4943.69 |  -23550.96
# 2023-05-10 13:53:12  | Income          | Business Income | Other                |     1611.6 |  -21939.36
# 2023-08-06 10:03:31  | Expense         | Education       | Credit Card          |      420.8 |  -22360.16
# 2023-10-17 11:03:11  | Expense         | Bills           | Debit Card           |    3309.97 |  -25670.13
# 2023-07-05 08:22:03  | Expense         | Education       | Other                |    2722.92 |  -28393.05
# 2023-07-02 20:27:24  | Expense         | Health          | UPI                  |    4831.23 |  -33224.28
# 2023-04-06 01:44:18  | Income          | Salary          | Credit Card          |      880.8 |  -32343.48
# 2023-06-15 23:35:29  | Income          | Gifts           | Cash                 |    4882.97 |  -27460.51
# 2023-08-19 11:13:42  | Expense         | Health          | UPI                  |    1106.62 |  -28567.13
# 2023-09-09 07:08:48  | Expense         | Housing         | Credit Card          |    2746.63 |  -31313.76
# 2023-03-31 10:06:22  | Income          | Salary          | Credit Card          |    4383.49 |  -26930.27
# 2023-11-02 19:01:25  | Expense         | Travel          | Mobile Wallet        |    1496.91 |  -28427.18
# 2023-10-20 03:22:47  | Income          | Investments     | Mobile Wallet        |    2709.76 |  -25717.42
# 2023-12-25 02:24:17  | Expense         | Housing         | Other                |     890.18 |   -26607.6
# 2023-01-29 01:30:11  | Expense         | Housing         | Cash                 |    3795.84 |  -30403.44
# 2023-12-31 03:13:57  | Expense         | Education       | Credit Card          |     329.39 |  -30732.83
# 2023-03-04 09:01:51  | Expense         | Shopping        | Credit Card          |     3724.1 |  -34456.93
# 2023-09-04 19:22:42  | Expense         | Transport       | Other                |    2788.72 |  -37245.65
# 2023-08-16 15:03:39  | Income          | Gifts           | Cash                 |     373.83 |  -36871.82
# 2023-05-24 09:03:43  | Expense         | Entertainment   | Bank to Bank         |    4458.76 |  -41330.58
# 2023-09-30 14:19:35  | Income          | Investments     | UPI                  |     4418.4 |  -36912.18
# 2023-03-11 01:11:26  | Expense         | Education       | Credit Card          |     624.38 |  -37536.56
# 2023-07-11 07:04:22  | Income          | Freelance       | Other                |    2004.23 |  -35532.33
# 2023-05-31 03:02:59  | Income          | Business Income | Other                |    1044.53 |   -34487.8
# 2023-08-28 01:31:57  | Expense         | Miscellaneous   | Credit Card          |    3336.78 |  -37824.58
# 2023-08-05 03:09:21  | Expense         | Health          | Debit Card           |    1264.14 |  -39088.72
# 2023-07-22 01:44:35  | Income          | Freelance       | Cash                 |     809.74 |  -38278.98
# 2023-07-30 21:07:54  | Expense         | Shopping        | Cash                 |    4242.27 |  -42521.25
# 2024-01-31 18:22:57  | Expense         | Transport       | Credit Card          |     157.51 |  -42678.76
# 2023-09-19 10:49:06  | Expense         | Housing         | Bank to Bank         |    4633.42 |  -47312.18
# 2023-07-02 07:36:31  | Expense         | Housing         | Bank to Bank         |     561.42 |   -47873.6
# 2023-02-12 14:29:24  | Expense         | Transport       | Credit Card          |     359.74 |  -48233.34
# 2023-06-09 04:18:58  | Expense         | Shopping        | Debit Card           |    4446.85 |  -52680.19
# 2023-01-09 08:20:16  | Expense         | Travel          | Bank to Bank         |    3110.94 |  -55791.13
# 2023-02-08 18:03:12  | Expense         | Health          | Cash                 |    3583.25 |  -59374.38
# 2023-10-15 02:14:55  | Income          | Salary          | Bank to Bank         |    3186.03 |  -56188.35
# 2023-07-03 15:48:53  | Expense         | Health          | Cash                 |     407.81 |  -56596.16
# 2024-01-26 17:49:29  | Income          | Freelance       | Bank to Bank         |    3210.64 |  -53385.52
# 2023-01-25 19:10:31  | Income          | Other           | Debit Card           |    4422.04 |  -48963.48
# 2023-11-30 01:00:51  | Expense         | Education       | Cash                 |    4459.62 |   -53423.1
# 2023-02-05 23:53:07  | Income          | Rental Income   | Bank to Bank         |     898.86 |  -52524.24
# 2023-07-29 18:09:59  | Expense         | Transport       | Cash                 |    4195.13 |  -56719.37
# 2023-06-06 14:04:12  | Income          | Business Income | Cash                 |    4647.79 |  -52071.58
# 2023-05-04 00:46:00  | Income          | Other           | Cash                 |    3668.24 |  -48403.34
# 2023-06-25 04:51:44  | Income          | Rental Income   | Debit Card           |     923.51 |  -47479.83
# 2023-02-25 09:44:28  | Income          | Business Income | Mobile Wallet        |    3584.18 |  -43895.65
# 2023-02-06 18:31:33  | Expense         | Food            | Debit Card           |    1702.99 |  -45598.64
# 2023-03-13 20:15:00  | Income          | Gifts           | Bank to Bank         |    2473.85 |  -43124.79
# 2023-08-15 19:35:09  | Expense         | Housing         | Other                |     968.52 |  -44093.31
# 2023-03-07 11:16:10  | Income          | Investments     | Credit Card          |    3756.65 |  -40336.66
# 2023-02-26 05:38:00  | Expense         | Health          | Debit Card           |    1341.02 |  -41677.68
# 2023-05-04 07:31:48  | Income          | Other           | Debit Card           |    3165.63 |  -38512.05
# 2023-10-31 23:10:46  | Income          | Business Income | Credit Card          |    1347.32 |  -37164.73
# 2023-11-27 17:15:36  | Income          | Other           | Debit Card           |    3769.79 |  -33394.94
# 2023-09-06 11:48:15  | Expense         | Education       | Mobile Wallet        |    3994.36 |   -37389.3
# 2023-02-03 11:29:31  | Expense         | Food            | Other                |     215.96 |  -37605.26
# 2023-01-09 16:08:28  | Income          | Business Income | Mobile Wallet        |    2677.78 |  -34927.48
# ...
# 2023-05-13 06:18:39  | Gifts           | Other                |    4259.42 |   75607.87
# 2023-05-25 07:13:22  | Business Income | Credit Card          |    2946.48 |   78554.35
# 2023-05-05 05:33:41  | Gifts           | Cash                 |     703.62 |   72546.57
# 2023-09-29 11:09:32  | Salary          | Credit Card          |    3868.82 |   76415.39
# 2023-06-26 18:03:11  | Freelance       | Other                |      470.9 |   76886.29
# 2023-06-25 08:56:05  | Other           | Cash                 |    1714.29 |   78600.58
# 2023-04-13 19:13:13  | Gifts           | Credit Card          |    2217.77 |   80818.35
# 2023-10-29 21:55:04  | Freelance       | Other                |    3147.79 |   83966.14
# 2023-08-28 22:02:04  | Investments     | Cash                 |    1629.11 |   85595.25
# 2023-02-15 13:00:36  | Investments     | Bank to Bank         |    1481.41 |   83332.87
# 2023-06-10 19:58:08  | Salary          | Bank to Bank         |    1721.66 |    82933.1
# 2023-05-09 07:16:19  | Freelance       | Cash                 |    2115.71 |   85048.81
# 2023-02-10 18:43:01  | Freelance       | Other                |     2823.6 |   81364.78
# 2023-06-21 19:16:20  | Other           | Cash                 |     672.48 |   82037.26
# 2023-01-07 01:38:10  | Other           | Other                |    4696.23 |   84281.24
# 2023-06-03 05:24:47  | Other           | Debit Card           |    4902.72 |   80109.64
# 2023-04-09 15:43:12  | Business Income | Bank to Bank         |    3170.81 |   82152.18
# 2023-12-18 03:03:13  | Rental Income   | Bank to Bank         |    4965.75 |   87117.93
# 2023-06-29 23:35:29  | Freelance       | Debit Card           |    4147.38 |   83415.87
# 2023-08-09 03:12:20  | Other           | UPI                  |     912.71 |   76262.01
# 2023-11-21 05:55:09  | Gifts           | Cash                 |    1135.18 |   71582.02
# 2023-10-27 05:43:36  | Business Income | Bank to Bank         |    2012.88 |    73594.9
# 2023-09-28 06:03:19  | Business Income | UPI                  |     883.29 |   72592.12
# 2023-01-08 09:47:31  | Salary          | Mobile Wallet        |     207.15 |   72799.27
# 2023-11-18 12:32:48  | Investments     | Cash                 |    1220.64 |   74019.91
# 2023-10-27 09:51:58  | Business Income | Credit Card          |    2632.69 |    64178.3
# 2024-01-09 12:27:08  | Gifts           | Debit Card           |    3865.21 |   66901.56
# 2023-12-26 07:05:50  | Other           | Other                |    4414.31 |   67102.01
# 2023-02-21 04:59:48  | Rental Income   | Other                |    3385.68 |   70487.69
# 2023-11-05 17:20:05  | Salary          | Other                |     2027.2 |    69048.0
# 2023-03-31 12:49:02  | Investments     | UPI                  |    3688.75 |   72736.75
# 2023-08-29 20:57:11  | Business Income | Credit Card          |    4273.78 |   77010.53
# 2024-01-15 05:08:56  | Freelance       | Credit Card          |     130.45 |   75634.68
# 2023-09-18 02:43:58  | Freelance       | Debit Card           |     224.19 |   66917.72
# 2023-06-08 17:27:00  | Gifts           | UPI                  |    4765.81 |   66514.74
# 2023-09-08 20:43:05  | Investments     | UPI                  |    2621.23 |   69135.97
# 2023-10-01 08:11:33  | Business Income | Bank to Bank         |    4975.35 |   74111.32
# 2023-06-22 03:47:13  | Gifts           | Mobile Wallet        |    3583.59 |   68096.02
# 2023-08-15 21:29:23  | Salary          | Bank to Bank         |     3198.4 |   68708.76
# 2023-02-24 00:06:39  | Freelance       | Cash                 |    4187.35 |   72896.11
# 2023-03-05 12:21:28  | Rental Income   | Mobile Wallet        |    3014.53 |   71703.41
# 2023-12-29 11:35:35  | Salary          | Bank to Bank         |    2701.75 |   70123.85
# 2023-02-12 05:08:00  | Other           | UPI                  |    3639.57 |   73763.42
# 2023-01-14 17:05:17  | Salary          | Bank to Bank         |    3752.95 |    69549.3
# 2023-04-03 10:36:50  | Salary          | Mobile Wallet        |     109.09 |   69658.39
# 2023-11-26 07:16:48  | Rental Income   | Cash                 |    3922.16 |   73580.55
# 2023-07-18 11:34:08  | Other           | Bank to Bank         |    3176.46 |   65624.35
# 2023-11-11 00:51:53  | Rental Income   | Debit Card           |     4574.1 |   69330.85
# 2023-03-28 01:25:42  | Rental Income   | Bank to Bank         |    2450.78 |   71781.63
# 2023-08-11 16:54:57  | Investments     | UPI                  |     547.28 |   72328.91
# 2023-07-31 03:20:07  | Rental Income   | Bank to Bank         |    4583.35 |   69399.89
# 2023-09-03 10:53:30  | Freelance       | Credit Card          |    1204.59 |   70604.48
# 2023-02-28 16:41:01  | Investments     | Mobile Wallet        |    1170.65 |   68207.84
# 2023-11-12 07:16:56  | Other           | Mobile Wallet        |    4868.56 |   66800.24
# 2023-09-16 16:53:19  | Investments     | UPI                  |     4976.3 |   71776.54
# 2023-03-14 01:02:49  | Salary          | Other                |     112.54 |   71889.08
# 2024-01-14 20:48:59  | Freelance       | UPI                  |    4462.21 |   75574.82
# 2023-09-19 05:32:42  | Investments     | Other                |    4760.43 |   73038.16
# 2023-07-05 07:16:08  | Salary          | Mobile Wallet        |    3603.84 |   73458.93
# 2023-11-27 09:38:00  | Salary          | UPI                  |     4996.2 |   78455.13
# 2023-09-15 20:02:57  | Investments     | Bank to Bank         |    2978.58 |   81433.71
# 2023-10-14 03:03:08  | Salary          | Mobile Wallet        |     760.44 |   82194.15
# 2023-08-24 11:18:16  | Business Income | Cash                 |    4504.05 |   82077.17
# 2023-05-27 20:38:24  | Other           | Credit Card          |    3080.19 |   85157.36
# 2023-05-13 08:44:36  | Other           | Mobile Wallet        |     976.17 |   83039.92
# 2023-03-31 15:20:29  | Rental Income   | Bank to Bank         |    2638.19 |   85678.11
# 2023-04-19 08:18:33  | Rental Income   | Mobile Wallet        |     3593.0 |   86457.18
# 2023-07-23 07:34:30  | Salary          | Bank to Bank         |    4691.43 |   91148.61
# 2023-05-30 23:34:56  | Other           | Mobile Wallet        |    1682.37 |   82317.05
# 2023-03-01 06:40:29  | Salary          | Debit Card           |    3252.96 |   85570.01
# 2023-03-05 05:06:21  | Gifts           | Mobile Wallet        |    1677.32 |   85838.93
# 2023-07-20 07:14:46  | Salary          | Debit Card           |    1519.18 |   87358.11
# 2023-02-12 21:20:48  | Gifts           | Bank to Bank         |    4249.68 |   91607.79
# 2023-11-07 17:58:08  | Rental Income   | Debit Card           |     976.55 |   92151.22
# 2023-09-19 21:17:02  | Other           | Cash                 |    3185.01 |   92973.87
# 2023-01-08 19:07:59  | Freelance       | Credit Card          |    2398.12 |   95371.99
# 2023-07-22 02:59:32  | Business Income | UPI                  |    2639.83 |    87743.1
# 2023-04-14 17:32:39  | Investments     | Bank to Bank         |    1796.42 |   89539.52
# 2024-01-27 19:32:41  | Salary          | Cash                 |     919.04 |   88126.65
# 2023-06-28 13:31:55  | Business Income | Other                |    3149.58 |   91276.23
# 2023-03-22 13:30:45  | Other           | Credit Card          |    2269.03 |    90537.1
# 2023-06-24 23:13:50  | Rental Income   | UPI                  |     238.41 |   89705.71
# 2024-01-10 14:29:46  | Other           | Credit Card          |    1548.79 |    91254.5
# 2023-11-24 06:40:43  | Gifts           | UPI                  |    1598.74 |   91239.46
# 2023-09-10 07:54:57  | Gifts           | Debit Card           |     448.39 |   80231.69
# 2024-01-11 13:15:47  | Investments     | UPI                  |    4407.48 |   84639.17
# 2023-01-15 17:14:14  | Business Income | Cash                 |    3710.03 |   84888.44
# 2023-12-04 13:39:13  | Business Income | UPI                  |     4069.2 |   84703.59
# 2023-12-12 05:47:54  | Other           | Debit Card           |    4964.34 |   89667.93
# ===========================================================================
#
#
#
# ==================================================
#               📌 EXPENSE TRACKER MENU
# ==================================================
#  1. 💸 Make a Transaction
#  2. 📜 Display All Transactions
#  3. 📉 Display Only Expense Transactions
#  4. 📈 Display Only Income Transactions
#  5. 📊 Display Expenses by Categories
#  6. 📂 Display Income by Categories
#  7. 📊 Generate Visualization Reports
#  8. ❓ Help (Operations List)
#  0. 🚪 Exit Application
# ==================================================
#
#
# =================================================================
#                       📊 EXPENSES BY CATEGORY
# =================================================================
# Category                  |    Total Amount
# -----------------------------------------------------------------
# Bills                     |        272786.5
# Education                 |       240074.77
# Entertainment             |        219610.6
# Food                      |       305252.87
# Health                    |       278171.56
# Housing                   |       250077.95
# Miscellaneous             |        248425.0
# Shopping                  |       241803.08
# Transport                 |       238275.15
# Travel                    |       251579.45
# =================================================================
#
#
#
# ==================================================
#               📌 EXPENSE TRACKER MENU
# ==================================================
#  1. 💸 Make a Transaction
#  2. 📜 Display All Transactions
#  3. 📉 Display Only Expense Transactions
#  4. 📈 Display Only Income Transactions
#  5. 📊 Display Expenses by Categories
#  6. 📂 Display Income by Categories
#  7. 📊 Generate Visualization Reports
#  8. ❓ Help (Operations List)
#  0. 🚪 Exit Application
# ==================================================
#
#
# =================================================================
#                        💰 INCOME BY CATEGORY
# =================================================================
# Category                  |    Total Amount
# -----------------------------------------------------------------
# Business Income           |       387868.69
# Freelance                 |       339757.71
# Gifts                     |       434410.23
# Investments               |        293958.5
# Other                     |       418565.13
# Rental Income             |       383933.02
# Salary                    |       365134.85
# =================================================================
#
#
#
# ==================================================
#               📌 EXPENSE TRACKER MENU
# ==================================================
#  1. 💸 Make a Transaction
#  2. 📜 Display All Transactions
#  3. 📉 Display Only Expense Transactions
#  4. 📈 Display Only Income Transactions
#  5. 📊 Display Expenses by Categories
#  6. 📂 Display Income by Categories
#  7. 📊 Generate Visualization Reports
#  8. ❓ Help (Operations List)
#  0. 🚪 Exit Application
# ==================================================
#
#
# --------------------------------------------------
#              📊 VISUALIZATION OPTIONS
# --------------------------------------------------
#  1. 📊 Income vs Expense
#  2. 📌 Expense by Categories
#  3. 📆 Expense by Months
#  4. 📂 Income by Categories
#  5. 📅 Income by Months
# --------------------------------------------------
# ==================================================
#               📌 EXPENSE TRACKER MENU
# ==================================================
#  1. 💸 Make a Transaction
#  2. 📜 Display All Transactions
#  3. 📉 Display Only Expense Transactions
#  4. 📈 Display Only Income Transactions
#  5. 📊 Display Expenses by Categories
#  6. 📂 Display Income by Categories
#  7. 📊 Generate Visualization Reports
#  8. ❓ Help (Operations List)
#  0. 🚪 Exit Application
# ==================================================
#
#
# --------------------------------------------------
#              📊 VISUALIZATION OPTIONS
# --------------------------------------------------
#  1. 📊 Income vs Expense
#  2. 📌 Expense by Categories
#  3. 📆 Expense by Months
#  4. 📂 Income by Categories
#  5. 📅 Income by Months
# --------------------------------------------------
# ==================================================
#               📌 EXPENSE TRACKER MENU
# ==================================================
#  1. 💸 Make a Transaction
#  2. 📜 Display All Transactions
#  3. 📉 Display Only Expense Transactions
#  4. 📈 Display Only Income Transactions
#  5. 📊 Display Expenses by Categories
#  6. 📂 Display Income by Categories
#  7. 📊 Generate Visualization Reports
#  8. ❓ Help (Operations List)
#  0. 🚪 Exit Application
# ==================================================
#
#
# --------------------------------------------------
#              📊 VISUALIZATION OPTIONS
# --------------------------------------------------
#  1. 📊 Income vs Expense
#  2. 📌 Expense by Categories
#  3. 📆 Expense by Months
#  4. 📂 Income by Categories
#  5. 📅 Income by Months
# --------------------------------------------------
# C:\Users\THINKPAD\AppData\Local\Temp\ipykernel_16772\1690362616.py:89: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   expense_df['Month'] = expense_df['Date'].dt.to_period('M').astype(str)
# ==================================================
#               📌 EXPENSE TRACKER MENU
# ==================================================
#  1. 💸 Make a Transaction
#  2. 📜 Display All Transactions
#  3. 📉 Display Only Expense Transactions
#  4. 📈 Display Only Income Transactions
#  5. 📊 Display Expenses by Categories
#  6. 📂 Display Income by Categories
#  7. 📊 Generate Visualization Reports
#  8. ❓ Help (Operations List)
#  0. 🚪 Exit Application
# ==================================================
#
#
# --------------------------------------------------
#              📊 VISUALIZATION OPTIONS
# --------------------------------------------------
#  1. 📊 Income vs Expense
#  2. 📌 Expense by Categories
#  3. 📆 Expense by Months
#  4. 📂 Income by Categories
#  5. 📅 Income by Months
# --------------------------------------------------
# ==================================================
#               📌 EXPENSE TRACKER MENU
# ==================================================
#  1. 💸 Make a Transaction
#  2. 📜 Display All Transactions
#  3. 📉 Display Only Expense Transactions
#  4. 📈 Display Only Income Transactions
#  5. 📊 Display Expenses by Categories
#  6. 📂 Display Income by Categories
#  7. 📊 Generate Visualization Reports
#  8. ❓ Help (Operations List)
#  0. 🚪 Exit Application
# ==================================================
#
#
# --------------------------------------------------
#              📊 VISUALIZATION OPTIONS
# --------------------------------------------------
#  1. 📊 Income vs Expense
#  2. 📌 Expense by Categories
#  3. 📆 Expense by Months
#  4. 📂 Income by Categories
#  5. 📅 Income by Months
# --------------------------------------------------
# C:\Users\THINKPAD\AppData\Local\Temp\ipykernel_16772\1690362616.py:112: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   income_df['Month'] = income_df['Date'].dt.to_period('M').astype(str)
# ==================================================
#               📌 EXPENSE TRACKER MENU
# ==================================================
#  1. 💸 Make a Transaction
#  2. 📜 Display All Transactions
#  3. 📉 Display Only Expense Transactions
#  4. 📈 Display Only Income Transactions
#  5. 📊 Display Expenses by Categories
#  6. 📂 Display Income by Categories
#  7. 📊 Generate Visualization Reports
#  8. ❓ Help (Operations List)
#  0. 🚪 Exit Application
# ==================================================
#
#
# 🚀 Thank you for using the Expense Tracker! Goodbye! 👋
